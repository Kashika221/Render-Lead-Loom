# %%
import requests
from bs4 import BeautifulSoup
import nltk
import re
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords

# %%
# !pip install selenium
# Out:
# Requirement already satisfied: selenium in /usr/local/lib/python3.11/dist-packages (4.31.0)
# Requirement already satisfied: urllib3<3,>=1.26 in /usr/local/lib/python3.11/dist-packages (from urllib3[socks]<3,>=1.26->selenium) (2.3.0)
# Requirement already satisfied: trio~=0.17 in /usr/local/lib/python3.11/dist-packages (from selenium) (0.30.0)
# Requirement already satisfied: trio-websocket~=0.9 in /usr/local/lib/python3.11/dist-packages (from selenium) (0.12.2)
# Requirement already satisfied: certifi>=2021.10.8 in /usr/local/lib/python3.11/dist-packages (from selenium) (2025.1.31)
# Requirement already satisfied: typing_extensions~=4.9 in /usr/local/lib/python3.11/dist-packages (from selenium) (4.13.2)
# Requirement already satisfied: websocket-client~=1.8 in /usr/local/lib/python3.11/dist-packages (from selenium) (1.8.0)
# Requirement already satisfied: attrs>=23.2.0 in /usr/local/lib/python3.11/dist-packages (from trio~=0.17->selenium) (25.3.0)
# Requirement already satisfied: sortedcontainers in /usr/local/lib/python3.11/dist-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: idna in /usr/local/lib/python3.11/dist-packages (from trio~=0.17->selenium) (3.10)
# Requirement already satisfied: outcome in /usr/local/lib/python3.11/dist-packages (from trio~=0.17->selenium) (1.3.0.post0)
# Requirement already satisfied: sniffio>=1.3.0 in /usr/local/lib/python3.11/dist-packages (from trio~=0.17->selenium) (1.3.1)
# Requirement already satisfied: wsproto>=0.14 in /usr/local/lib/python3.11/dist-packages (from trio-websocket~=0.9->selenium) (1.2.0)
# Requirement already satisfied: pysocks!=1.5.7,<2.0,>=1.5.6 in /usr/local/lib/python3.11/dist-packages (from urllib3[socks]<3,>=1.26->selenium) (1.7.1)
# Requirement already satisfied: h11<1,>=0.9.0 in /usr/local/lib/python3.11/dist-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium) (0.14.0)

# %%
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# True

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
from bs4 import BeautifulSoup
import re
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
import time

nltk.download('punkt')
nltk.download('stopwords')

def setup_driver():
    options = Options()
    options.add_argument("--headless")
    options.add_argument("--disable-gpu")
    options.add_argument('--no-sandbox')
    driver = webdriver.Chrome(options=options)
    return driver

def scrape_website_info(url):
    driver = setup_driver()
    driver.get(url)
    time.sleep(3)

    soup = BeautifulSoup(driver.page_source, 'html.parser')


    title = soup.title.string.strip() if soup.title else ""


    meta_desc = ""
    meta_tag = soup.find('meta', attrs={'name': 'description'})
    if meta_tag and 'content' in meta_tag.attrs:
        meta_desc = meta_tag['content'].strip()


    h1_tags = [h1.get_text(strip=True) for h1 in soup.find_all('h1')]


    links = [a['href'] for a in soup.find_all('a', href=True) if 'about' in a['href'].lower()]
    about_content = ""
    if links:
        about_url = links[0]
        if about_url.startswith('/'):
            base_url = re.match(r'^https?://[^/]+', url).group(0)
            about_url = base_url + about_url
        driver.get(about_url)
        time.sleep(2)
        about_soup = BeautifulSoup(driver.page_source, 'html.parser')
        paragraphs = about_soup.find_all('p')
        about_content = ' '.join(p.get_text() for p in paragraphs)
        about_content = about_content.strip()[:3000]

    homepage_paragraphs = soup.find_all('p')
    homepage_text = ' '.join(p.get_text() for p in homepage_paragraphs)
    homepage_text = homepage_text.strip()[:3000]

    driver.quit()

    return {
        'title': title,
        'meta_description': meta_desc,
        'h1_tags': h1_tags,
        'about_content': about_content,
        'homepage_text': homepage_text
    }

def get_main_keywords(text, limit=8):
    text = re.sub(r'[^\w\s]', '', text.lower())
    tokens = word_tokenize(text)
    stop_words = set(stopwords.words('english'))
    words = [word for word in tokens if word.isalpha() and word not in stop_words and len(word) > 2]

    relevant_words = [
        'marketing', 'growth', 'strategy', 'brand', 'experience', 'customers',
        'clients', 'design', 'technology', 'innovation', 'solutions', 'services',
        'campaigns', 'team', 'creative', 'performance', 'development', 'results',
        'insights', 'business', 'products', 'reach', 'digital', 'engagement'
    ]

    filtered = [word for word in words if word in relevant_words]
    frequency = {}
    for word in filtered:
        frequency[word] = frequency.get(word, 0) + 1

    sorted_keywords = sorted(frequency.items(), key=lambda x: x[1], reverse=True)
    return [kw[0] for kw in sorted_keywords[:limit]]

def write_brand_summary(url, keywords, site_info):
    if not keywords:
        return (
            f"{site_info['title'] if site_info['title'] else url} is a digital agency helping businesses grow through strategic marketing and performance-driven solutions. "
            f"The team focuses on delivering measurable results through creativity and execution."
        )

    key_areas = keywords[:3]
    support_areas = keywords[3:5] if len(keywords) > 4 else keywords[:2]

    return (
        f"{site_info['title'] if site_info['title'] else url} is a results-driven digital agency specializing in {key_areas[0]}, {key_areas[1]}, and {key_areas[2]}. "
        f"With a strong foundation in {support_areas[0]} and {support_areas[1] if len(support_areas) > 1 else key_areas[0]}, "
        f"the agency delivers tailored solutions that align with real business goals."
    )
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
websites = [
    "https://marketingmasala.com/",
    "https://inklik.com/"
]

# %%
for site in websites:
    site_info = scrape_website_info(site)
    combined_text = site_info['about_content'] + " " + site_info['homepage_text']

    if len(combined_text) < 200:
        print(f"Skipped {site} due to low content quality.")
        continue

    keywords = get_main_keywords(combined_text)
    summary = write_brand_summary(site, keywords, site_info)

    print(f"Website: {site}")
    print(f"Title: {site_info['title']}")
    print(f"Meta Description: {site_info['meta_description']}")
    print(f"H1 Tags: {site_info['h1_tags']}")
    print(f"Keywords: {keywords}")
    print(f"Brand Summary: {summary}")
    print("-" * 100)
# Out:
# Website: https://marketingmasala.com/
# Title: Growth-Focused Digital Marketing Agency | Marketing Masala
# Meta Description: Marketing Masala is a paid media marketing agency working with clients across 5 continents. We help eCommerce, Mobile Apps, Edtech, and SaaS businesses grow better.
# H1 Tags: []
# Keywords: ['marketing', 'growth', 'team', 'business', 'digital', 'creative', 'design', 'experience']
# Brand Summary: Growth-Focused Digital Marketing Agency | Marketing Masala is a results-driven digital agency specializing in marketing, growth, and team. With a strong foundation in business and digital, the agency delivers tailored solutions that align with real business goals.
# ----------------------------------------------------------------------------------------------------
# Website: https://inklik.com/
# Title: Best Digital Marketing Agency in Delhi NCR - Inklik.com
# Meta Description: Best Digital marketing agency in Delhi NCR with certified digital marketing experts for all Online Marketing Services ✔SEO ✔Social Media Marketing ✔SMO ✔PPC
# H1 Tags: ['Best Digital Marketing Company in Delhi NCR']
# Keywords: ['marketing', 'digital', 'experience', 'team', 'business', 'clients', 'campaigns', 'customers']
# Brand Summary: Best Digital Marketing Agency in Delhi NCR - Inklik.com is a results-driven digital agency specializing in marketing, digital, and experience. With a strong foundation in team and business, the agency delivers tailored solutions that align with real business goals.
# ----------------------------------------------------------------------------------------------------

# %% [markdown]
# This script is built to automatically generate brand summaries by scraping the "About Us" section from a list of company websites. It starts by locating and extracting relevant content from each site’s About page, then processes that content to find the most frequently mentioned business-related keywords. These keywords are used to generate a concise and informative brand positioning summary, ideal for lead enrichment, profiling, or content drafting.
#
# The keyword extraction logic filters out common stopwords and focuses on industry-relevant terms like “marketing,” “strategy,” and “growth.” The final output includes the website URL, extracted keywords, and a custom-written summary that reflects the brand’s core services and values. If no sufficient content is found, the script skips the site to maintain quality.

# %%
# !pip install -q -U google-genai
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 159.7/159.7 kB 6.7 MB/s eta 0:00:00

# %%
from google import genai
from google.genai import types
prompt = list(summary)
client = genai.Client(api_key = "AIzaSyDLFpzc47AQdX-TbdlWaJs8vPVDXCebq7o")
response = client.models.generate_content(
    model = "gemini-2.0-flash",
    contents = prompt,
    config = types.GenerateContentConfig(
        max_output_tokens = 1000,
        temperature = 0.1,
        system_instruction = "generate complete latex code to create ppt to pitch to the company"
    )
)
print(response.text)
# Out:
# ```latex
# \documentclass{beamer}
#
# \usepackage{graphicx}
# \usepackage{amsmath}
# \usepackage{amssymb}
# \usepackage{hyperref}
# \usepackage{color}
# \usepackage{ragged2e} % For justified text in frames
#
# \usetheme{default} % Or choose another theme like 'Madrid', 'Berlin', etc.
#
# \title{Inklik: Driving Digital Success}
# \author{Your Name/Team Name}
# \date{\today}
#
# \begin{document}
#
# \begin{frame}
# \titlepage
# \end{frame}
#
# \begin{frame}
# \frametitle{The Challenge: Navigating the Digital Landscape}
#
# \begin{itemize}
#     \item The digital world is constantly evolving.
#     \item Businesses need to stay ahead to remain competitive.
#     \item Achieving real business goals requires a strategic and tailored approach.
# \end{itemize}
#
# \end{frame}
#
# \begin{frame}
# \frametitle{Introducing Inklik: Your Results-Driven Digital Partner}
#
# \begin{itemize}
#     \item \textbf{Who We Are:} A digital agency specializing in digital, marketing, and experience.
#     \item \textbf{Our Focus:} Delivering tailored solutions that align with real business goals.
#     \item \textbf{Our Strength:} A strong foundation in clients and business.
# \end{itemize}
#
# \includegraphics[width=0.4\textwidth]{example-image-a} % Replace with Inklik logo or relevant image
# \end{frame}
#
# \begin{frame}
# \frametitle{Our Expertise: Digital, Marketing, and Experience}
#
# \begin{columns}
#     \begin{column}{0.3\textwidth}
#         \textbf{Digital}
#         \begin{itemize}
#             \item SEO
#             \item PPC
#             \item Web Development
#             \item Data Analytics
#         \end{itemize}
#     \end{column}
#     \begin{column}{0.3\textwidth}
#         \textbf{Marketing}
#         \begin{itemize}
#             \item Content Marketing
#             \item Social Media Marketing
#             \item Email Marketing
#             \item Brand Strategy
#         \end{itemize}
#     \end{column}
#     \begin{column}{0.3\textwidth}
#         \textbf{Experience}
#         \begin{itemize}
#             \item User Experience (UX) Design
#             \item Customer Journey Mapping
#             \item Conversion Rate Optimization (CRO)
#         \end{itemize}
#     \end{column}
# \end{columns}
#
# \end{frame}
#
# \begin{frame}
# \frametitle{Tailored Solutions for Real Business Goals}
#
# \begin{itemize}
#     \item We don't offer one-size-fits-all solutions.
#     \item We take the time to understand your business, your goals, and your target audience.
#     \item We develop customized strategies that deliver measurable results.
# \end{itemize}
#
# \includegraphics[width=0.4\textwidth]{example-image-b} % Replace with an image representing tailored solutions
# \end{frame}
#
# \begin{frame}
# \frametitle{Our Approach: Results-Driven and Data-Informed}
#
# \begin{itemize}
#     \item \textbf{Data-Driven Insights:} We use data to inform our strategies and optimize performance.
#     \item \textbf{Continuous Improvement:} We constantly monitor and refine our approach to ensure maximum impact.
#     \item \textbf{Transparent Communication:} We keep you informed every step of the way.
# \end{itemize}
#
# \end{frame}
#
# \begin{frame}
# \frametitle{Case Study: [Client Name] - Achieving [Specific Result]}
#
# \textbf{Challenge:} [Briefly describe the client's challenge]
#
# \textbf{Solution:} [Outline the solution Inklik provided]
#
# \textbf{Results:} [Quantifiable results achieved, e.g., increased website traffic, higher conversion rates, improved ROI]
#
# \includegraphics[width=0.4\textwidth]{example-image-c} % Replace with a relevant image from the case study
# \end{frame}
#
# \begin{frame}
# \frametitle{Why Choose Inklik?}
#
# \begin{itemize}
#     \item \textbf{Expertise:} Proven track record in digital, marketing, and experience.
#     \item \textbf{Tailored Solutions:} Customized strategies that align with your business goals.
#     \item \textbf{Results-Driven Approach:} Focus on delivering measurable results and ROI.
#     \item \textbf{Strong Foundation

# %%
file = open("pitch.tex", "w")
code = str(response.text).replace("```latex", "")
file.write(code)
file.close()

# %%
# !pip install pdflatex
# Out:
# Collecting pdflatex
#   Downloading pdflatex-0.1.3-py3-none-any.whl.metadata (3.4 kB)
# Collecting attrs<19.0,>=18.2 (from pdflatex)
#   Downloading attrs-18.2.0-py2.py3-none-any.whl.metadata (11 kB)
# Downloading pdflatex-0.1.3-py3-none-any.whl (8.3 kB)
# Downloading attrs-18.2.0-py2.py3-none-any.whl (34 kB)
# Installing collected packages: attrs, pdflatex
#   Attempting uninstall: attrs
#     Found existing installation: attrs 25.3.0
#     Uninstalling attrs-25.3.0:
#       Successfully uninstalled attrs-25.3.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# jsonschema 4.23.0 requires attrs>=22.2.0, but you have attrs 18.2.0 which is incompatible.
# referencing 0.36.2 requires attrs>=22.2.0, but you have attrs 18.2.0 which is incompatible.
# Successfully installed attrs-18.2.0 pdflatex-0.1.3

# %%
# !sudo apt install texlive-latex-base
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   dvisvgm fonts-droid-fallback fonts-lmodern fonts-noto-mono fonts-urw-base35
#   libgs9 libgs9-common libidn12 libijs-0.35 libjbig2dec0 libkpathsea6
#   libptexenc1 libsynctex2 libteckit0 libtexlua53 libtexluajit2 libwoff1
#   libzzip-0-13 lmodern poppler-data t1utils tex-common texlive-base
#   texlive-binaries xfonts-encodings xfonts-utils
# Suggested packages:
#   fonts-noto fonts-freefont-otf | fonts-freefont-ttf fonts-texgyre
#   poppler-utils ghostscript fonts-japanese-mincho | fonts-ipafont-mincho
#   fonts-japanese-gothic | fonts-ipafont-gothic fonts-arphic-ukai
#   fonts-arphic-uming fonts-nanum debhelper gv | postscript-viewer perl-tk xpdf
#   | pdf-viewer xzdec texlive-latex-base-doc
# The following NEW packages will be installed:
#   dvisvgm fonts-droid-fallback fonts-lmodern fonts-noto-mono fonts-urw-base35
#   libgs9 libgs9-common libidn12 libijs-0.35 libjbig2dec0 libkpathsea6
#   libptexenc1 libsynctex2 libteckit0 libtexlua53 libtexluajit2 libwoff1
#   libzzip-0-13 lmodern poppler-data t1utils tex-common texlive-base
#   texlive-binaries texlive-latex-base xfonts-encodings xfonts-utils
# 0 upgraded, 27 newly installed, 0 to remove and 30 not upgraded.
# Need to get 65.7 MB of archives.
# After this operation, 222 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/main amd64 fonts-droid-fallback all 1:6.0.1r16-1.1build1 [1,805 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/main amd64 poppler-data all 0.4.11-1 [2,171 kB]
# Get:3 http://archive.ubuntu.com/ubuntu jammy/universe amd64 tex-common all 6.17 [33.7 kB]
# Get:4 http://archive.ubuntu.com/ubuntu jammy/main amd64 fonts-urw-base35 all 20200910-1 [6,367 kB]
# Get:5 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libgs9-common all 9.55.0~dfsg1-0ubuntu5.11 [753 kB]
# Get:6 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libidn12 amd64 1.38-4ubuntu1 [60.0 kB]
# Get:7 http://archive.ubuntu.com/ubuntu jammy/main amd64 libijs-0.35 amd64 0.35-15build2 [16.5 kB]
# Get:8 http://archive.ubuntu.com/ubuntu jammy/main amd64 libjbig2dec0 amd64 0.19-3build2 [64.7 kB]
# Get:9 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libgs9 amd64 9.55.0~dfsg1-0ubuntu5.11 [5,031 kB]
# Get:10 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libkpathsea6 amd64 2021.20210626.59705-1ubuntu0.2 [60.4 kB]
# Get:11 http://archive.ubuntu.com/ubuntu jammy/main amd64 libwoff1 amd64 1.0.2-1build4 [45.2 kB]
# Get:12 http://archive.ubuntu.com/ubuntu jammy/universe amd64 dvisvgm amd64 2.13.1-1 [1,221 kB]
# Get:13 http://archive.ubuntu.com/ubuntu jammy/universe amd64 fonts-lmodern all 2.004.5-6.1 [4,532 kB]
# Get:14 http://archive.ubuntu.com/ubuntu jammy/main amd64 fonts-noto-mono all 20201225-1build1 [397 kB]
# Get:15 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libptexenc1 amd64 2021.20210626.59705-1ubuntu0.2 [39.1 kB]
# Get:16 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libsynctex2 amd64 2021.20210626.59705-1ubuntu0.2 [55.6 kB]
# Get:17 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libteckit0 amd64 2.5.11+ds1-1 [421 kB]
# Get:18 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libtexlua53 amd64 2021.20210626.59705-1ubuntu0.2 [120 kB]
# Get:19 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libtexluajit2 amd64 2021.20210626.59705-1ubuntu0.2 [267 kB]
# Get:20 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libzzip-0-13 amd64 0.13.72+dfsg.1-1.1 [27.0 kB]
# Get:21 http://archive.ubuntu.com/ubuntu jammy/main amd64 xfonts-encodings all 1:1.0.5-0ubuntu2 [578 kB]
# Get:22 http://archive.ubuntu.com/ubuntu jammy/main amd64 xfonts-utils amd64 1:7.7+6build2 [94.6 kB]
# Get:23 http://archive.ubuntu.com/ubuntu jammy/universe amd64 lmodern all 2.004.5-6.1 [9,471 kB]
# Get:24 http://archive.ubuntu.com/ubuntu jammy/main amd64 t1utils amd64 1.41-4build2 [61.3 kB]
# Get:25 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 texlive-binaries amd64 2021.20210626.59705-1ubuntu0.2 [9,860 kB]
# Get:26 http://archive.ubuntu.com/ubuntu jammy/universe amd64 texlive-base all 2021.20220204-1 [21.0 MB]
# Get:27 http://archive.ubuntu.com/ubuntu jammy/universe amd64 texlive-latex-base all 2021.20220204-1 [1,128 kB]
# Fetched 65.7 MB in 6s (10.2 MB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78, <> line 27.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package fonts-droid-fallback.
# (Reading database ... 126315 files and directories currently installed.)
# Preparing to unpack .../00-fonts-droid-fallback_1%3a6.0.1r16-1.1build1_all.deb ...
# Unpacking fonts-droid-fallback (1:6.0.1r16-1.1build1) ...
# Selecting previously unselected package poppler-data.
# Preparing to unpack .../01-poppler-data_0.4.11-1_all.deb ...
# Unpacking poppler-data (0.4.11-1) ...
# Selecting previously unselected package tex-common.
# Preparing to unpack .../02-tex-common_6.17_all.deb ...
# Unpacking tex-common (6.17) ...
# Selecting previously unselected package fonts-urw-base35.
# Preparing to unpack .../03-fonts-urw-base35_20200910-1_all.deb ...
# Unpacking fonts-urw-base35 (20200910-1) ...
# Selecting previously unselected package libgs9-common.
# Preparing to unpack .../04-libgs9-common_9.55.0~dfsg1-0ubuntu5.11_all.deb ...
# Unpacking libgs9-common (9.55.0~dfsg1-0ubuntu5.11) ...
# Selecting previously unselected package libidn12:amd64.
# Preparing to unpack .../05-libidn12_1.38-4ubuntu1_amd64.deb ...
# Unpacking libidn12:amd64 (1.38-4ubuntu1) ...
# Selecting previously unselected package libijs-0.35:amd64.
# Preparing to unpack .../06-libijs-0.35_0.35-15build2_amd64.deb ...
# Unpacking libijs-0.35:amd64 (0.35-15build2) ...
# Selecting previously unselected package libjbig2dec0:amd64.
# Preparing to unpack .../07-libjbig2dec0_0.19-3build2_amd64.deb ...
# Unpacking libjbig2dec0:amd64 (0.19-3build2) ...
# Selecting previously unselected package libgs9:amd64.
# Preparing to unpack .../08-libgs9_9.55.0~dfsg1-0ubuntu5.11_amd64.deb ...
# Unpacking libgs9:amd64 (9.55.0~dfsg1-0ubuntu5.11) ...
# Selecting previously unselected package libkpathsea6:amd64.
# Preparing to unpack .../09-libkpathsea6_2021.20210626.59705-1ubuntu0.2_amd64.deb ...
# Unpacking libkpathsea6:amd64 (2021.20210626.59705-1ubuntu0.2) ...
# Selecting previously unselected package libwoff1:amd64.
# Preparing to unpack .../10-libwoff1_1.0.2-1build4_amd64.deb ...
# Unpacking libwoff1:amd64 (1.0.2-1build4) ...
# Selecting previously unselected package dvisvgm.
# Preparing to unpack .../11-dvisvgm_2.13.1-1_amd64.deb ...
# Unpacking dvisvgm (2.13.1-1) ...
# Selecting previously unselected package fonts-lmodern.
# Preparing to unpack .../12-fonts-lmodern_2.004.5-6.1_all.deb ...
# Unpacking fonts-lmodern (2.004.5-6.1) ...
# Selecting previously unselected package fonts-noto-mono.
# Preparing to unpack .../13-fonts-noto-mono_20201225-1build1_all.deb ...
# Unpacking fonts-noto-mono (20201225-1build1) ...
# Selecting previously unselected package libptexenc1:amd64.
# Preparing to unpack .../14-libptexenc1_2021.20210626.59705-1ubuntu0.2_amd64.deb ...
# Unpacking libptexenc1:amd64 (2021.20210626.59705-1ubuntu0.2) ...
# Selecting previously unselected package libsynctex2:amd64.
# Preparing to unpack .../15-libsynctex2_2021.20210626.59705-1ubuntu0.2_amd64.deb ...
# Unpacking libsynctex2:amd64 (2021.20210626.59705-1ubuntu0.2) ...
# Selecting previously unselected package libteckit0:amd64.
# Preparing to unpack .../16-libteckit0_2.5.11+ds1-1_amd64.deb ...
# Unpacking libteckit0:amd64 (2.5.11+ds1-1) ...
# Selecting previously unselected package libtexlua53:amd64.
# Preparing to unpack .../17-libtexlua53_2021.20210626.59705-1ubuntu0.2_amd64.deb ...
# Unpacking libtexlua53:amd64 (2021.20210626.59705-1ubuntu0.2) ...
# Selecting previously unselected package libtexluajit2:amd64.
# Preparing to unpack .../18-libtexluajit2_2021.20210626.59705-1ubuntu0.2_amd64.deb ...
# Unpacking libtexluajit2:amd64 (2021.20210626.59705-1ubuntu0.2) ...
# Selecting previously unselected package libzzip-0-13:amd64.
# Preparing to unpack .../19-libzzip-0-13_0.13.72+dfsg.1-1.1_amd64.deb ...
# Unpacking libzzip-0-13:amd64 (0.13.72+dfsg.1-1.1) ...
# Selecting previously unselected package xfonts-encodings.
# Preparing to unpack .../20-xfonts-encodings_1%3a1.0.5-0ubuntu2_all.deb ...
# Unpacking xfonts-encodings (1:1.0.5-0ubuntu2) ...
# Selecting previously unselected package xfonts-utils.
# Preparing to unpack .../21-xfonts-utils_1%3a7.7+6build2_amd64.deb ...
# Unpacking xfonts-utils (1:7.7+6build2) ...
# Selecting previously unselected package lmodern.
# Preparing to unpack .../22-lmodern_2.004.5-6.1_all.deb ...
# Unpacking lmodern (2.004.5-6.1) ...
# Selecting previously unselected package t1utils.
# Preparing to unpack .../23-t1utils_1.41-4build2_amd64.deb ...
# Unpacking t1utils (1.41-4build2) ...
# Selecting previously unselected package texlive-binaries.
# Preparing to unpack .../24-texlive-binaries_2021.20210626.59705-1ubuntu0.2_amd64.deb ...
# Unpacking texlive-binaries (2021.20210626.59705-1ubuntu0.2) ...
# Selecting previously unselected package texlive-base.
# Preparing to unpack .../25-texlive-base_2021.20220204-1_all.deb ...
# Unpacking texlive-base (2021.20220204-1) ...
# Selecting previously unselected package texlive-latex-base.
# Preparing to unpack .../26-texlive-latex-base_2021.20220204-1_all.deb ...
# Unpacking texlive-latex-base (2021.20220204-1) ...
# Setting up fonts-noto-mono (20201225-1build1) ...
# Setting up libwoff1:amd64 (1.0.2-1build4) ...
# Setting up libtexlua53:amd64 (2021.20210626.59705-1ubuntu0.2) ...
# Setting up libijs-0.35:amd64 (0.35-15build2) ...
# Setting up libtexluajit2:amd64 (2021.20210626.59705-1ubuntu0.2) ...
# Setting up libzzip-0-13:amd64 (0.13.72+dfsg.1-1.1) ...
# Setting up fonts-urw-base35 (20200910-1) ...
# Setting up poppler-data (0.4.11-1) ...
# Setting up tex-common (6.17) ...
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78.)
# debconf: falling back to frontend: Readline
# update-language: texlive-base not installed and configured, doing nothing!
# Setting up libjbig2dec0:amd64 (0.19-3build2) ...
# Setting up libteckit0:amd64 (2.5.11+ds1-1) ...
# Setting up xfonts-encodings (1:1.0.5-0ubuntu2) ...
# Setting up t1utils (1.41-4build2) ...
# Setting up libidn12:amd64 (1.38-4ubuntu1) ...
# Setting up libkpathsea6:amd64 (2021.20210626.59705-1ubuntu0.2) ...
# Setting up fonts-lmodern (2.004.5-6.1) ...
# Setting up fonts-droid-fallback (1:6.0.1r16-1.1build1) ...
# Setting up libsynctex2:amd64 (2021.20210626.59705-1ubuntu0.2) ...
# Setting up libgs9-common (9.55.0~dfsg1-0ubuntu5.11) ...
# Setting up libgs9:amd64 (9.55.0~dfsg1-0ubuntu5.11) ...
# Setting up dvisvgm (2.13.1-1) ...
# Setting up xfonts-utils (1:7.7+6build2) ...
# Setting up libptexenc1:amd64 (2021.20210626.59705-1ubuntu0.2) ...
# Setting up texlive-binaries (2021.20210626.59705-1ubuntu0.2) ...
# update-alternatives: using /usr/bin/xdvi-xaw to provide /usr/bin/xdvi.bin (xdvi.bin) in auto mode
# update-alternatives: using /usr/bin/bibtex.original to provide /usr/bin/bibtex (bibtex) in auto mode
# Setting up lmodern (2.004.5-6.1) ...
# Setting up texlive-base (2021.20220204-1) ...
# /usr/bin/ucfr
# /usr/bin/ucfr
# /usr/bin/ucfr
# /usr/bin/ucfr
# mktexlsr: Updating /var/lib/texmf/ls-R-TEXLIVEDIST...
# mktexlsr: Updating /var/lib/texmf/ls-R-TEXMFMAIN...
# mktexlsr: Updating /var/lib/texmf/ls-R...
# mktexlsr: Done.
# tl-paper: setting paper size for dvips to a4: /var/lib/texmf/dvips/config/config-paper.ps
# tl-paper: setting paper size for dvipdfmx to a4: /var/lib/texmf/dvipdfmx/dvipdfmx-paper.cfg
# tl-paper: setting paper size for xdvi to a4: /var/lib/texmf/xdvi/XDvi-paper
# tl-paper: setting paper size for pdftex to a4: /var/lib/texmf/tex/generic/tex-ini-files/pdftexconfig.tex
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78.)
# debconf: falling back to frontend: Readline
# Setting up texlive-latex-base (2021.20220204-1) ...
# Processing triggers for fontconfig (2.13.1-4.2ubuntu5) ...
# Processing triggers for libc-bin (2.35-0ubuntu3.8) ...
# /sbin/ldconfig.real: /usr/local/lib/libtcm.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm_debug.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc_proxy.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libhwloc.so.15 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_opencl.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_5.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbb.so.12 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_loader.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libumf.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_0.so.3 is not a symbolic link
#
# Processing triggers for man-db (2.10.2-1) ...
# Processing triggers for mailcap (3.70+nmu1ubuntu1) ...
# Processing triggers for tex-common (6.17) ...
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78.)
# debconf: falling back to frontend: Readline
# Running updmap-sys. This may take some time... done.
# Running mktexlsr /var/lib/texmf ... done.
# Building format(s) --all.
# 	This may take some time... done.

# %%
# !sudo apt install texlive-full
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   aglfn asymptote asymptote-doc biber chktex cm-super cm-super-minimal context
#   context-modules cups-bsd cups-client cups-common dvidvi dvipng feynmf
#   fonts-adf-accanthis fonts-adf-berenis fonts-adf-gillius
#   fonts-adf-universalis fonts-arphic-bkai00mp fonts-arphic-bsmi00lp
#   fonts-arphic-gbsn00lp fonts-arphic-gkai00mp fonts-arphic-uming fonts-baekmuk
#   fonts-cabin fonts-cantarell fonts-comfortaa fonts-croscore
#   fonts-crosextra-caladea fonts-crosextra-carlito fonts-dejavu-core
#   fonts-dejavu-extra fonts-ebgaramond fonts-ebgaramond-extra
#   fonts-font-awesome fonts-freefont-otf fonts-freefont-ttf fonts-gfs-artemisia
#   fonts-gfs-baskerville fonts-gfs-bodoni-classic fonts-gfs-complutum
#   fonts-gfs-didot fonts-gfs-didot-classic fonts-gfs-gazis
#   fonts-gfs-neohellenic fonts-gfs-olga fonts-gfs-porson fonts-gfs-solomos
#   fonts-gfs-theokritos fonts-go fonts-hosny-amiri fonts-ipaexfont-gothic
#   fonts-ipaexfont-mincho fonts-ipafont-gothic fonts-ipafont-mincho
#   fonts-junicode fonts-lato fonts-linuxlibertine fonts-lobster
#   fonts-lobstertwo fonts-noto-color-emoji fonts-noto-core
#   fonts-oflb-asana-math fonts-open-sans fonts-roboto-unhinted fonts-sil-charis
#   fonts-sil-gentium fonts-sil-gentium-basic fonts-sil-gentiumplus
#   fonts-sil-gentiumplus-compact fonts-sil-padauk fonts-stix fonts-texgyre
#   fonts-tlwg-garuda fonts-tlwg-garuda-otf fonts-tlwg-kinnari
#   fonts-tlwg-kinnari-otf fonts-tlwg-laksaman fonts-tlwg-laksaman-otf
#   fonts-tlwg-loma fonts-tlwg-loma-otf fonts-tlwg-mono fonts-tlwg-mono-otf
#   fonts-tlwg-norasi fonts-tlwg-norasi-otf fonts-tlwg-purisa
#   fonts-tlwg-purisa-otf fonts-tlwg-sawasdee fonts-tlwg-sawasdee-otf
#   fonts-tlwg-typewriter fonts-tlwg-typewriter-otf fonts-tlwg-typist
#   fonts-tlwg-typist-otf fonts-tlwg-typo fonts-tlwg-typo-otf fonts-tlwg-umpush
#   fonts-tlwg-umpush-otf fonts-tlwg-waree fonts-tlwg-waree-otf
#   fonts-unfonts-core fonts-unfonts-extra fragmaster freeglut3 ghostscript
#   gsfonts gsfonts-x11 imagemagick imagemagick-6-common imagemagick-6.q16 info
#   install-info lacheck latex-cjk-all latex-cjk-chinese
#   latex-cjk-chinese-arphic-bkai00mp latex-cjk-chinese-arphic-bsmi00lp
#   latex-cjk-chinese-arphic-gbsn00lp latex-cjk-chinese-arphic-gkai00mp
#   latex-cjk-common latex-cjk-japanese latex-cjk-japanese-wadalab
#   latex-cjk-korean latex-cjk-thai latexdiff latexmk lcdf-typetools
#   libalgorithm-c3-perl libapache-pom-java libauthen-sasl-perl
#   libautovivification-perl libb-hooks-endofscope-perl libb-hooks-op-check-perl
#   libbtparse2 libbusiness-isbn-data-perl libbusiness-isbn-perl
#   libbusiness-ismn-perl libbusiness-issn-perl libclass-accessor-perl
#   libclass-c3-perl libclass-c3-xs-perl libclass-data-inheritable-perl
#   libclass-inspector-perl libclass-method-modifiers-perl
#   libclass-singleton-perl libclass-xsaccessor-perl libclone-perl
#   libcommon-sense-perl libcommons-logging-java libcommons-parent-java
#   libdata-compare-perl libdata-dump-perl libdata-optlist-perl
#   libdata-uniqid-perl libdate-simple-perl libdatetime-calendar-julian-perl
#   libdatetime-format-builder-perl libdatetime-format-strptime-perl
#   libdatetime-locale-perl libdatetime-perl libdatetime-timezone-perl
#   libdevel-callchecker-perl libdevel-caller-perl
#   libdevel-globaldestruction-perl libdevel-lexalias-perl
#   libdevel-stacktrace-perl libdist-checkconflicts-perl libdjvulibre-text
#   libdjvulibre21 libdynaloader-functions-perl libemail-date-format-perl
#   libemf1 libencode-eucjpms-perl libencode-hanextra-perl libencode-jis2k-perl
#   libencode-locale-perl libencode-perl libeval-closure-perl libevdev2
#   libexception-class-perl libexporter-tiny-perl libfftw3-double3
#   libfile-find-rule-perl libfile-homedir-perl libfile-listing-perl
#   libfile-sharedir-perl libfile-slurper-perl libfile-which-perl
#   libfont-afm-perl libfontbox-java libgsl27 libgslcblas0 libgudev-1.0-0
#   libhtml-form-perl libhtml-format-perl libhtml-parser-perl
#   libhtml-tagset-perl libhtml-tree-perl libhttp-cookies-perl
#   libhttp-daemon-perl libhttp-date-perl libhttp-message-perl
#   libhttp-negotiate-perl libinput-bin libinput10 libio-html-perl
#   libio-socket-ssl-perl libipc-run3-perl libipc-shareable-perl libjson-perl
#   libjson-xs-perl libjxr-tools libjxr0 liblingua-translit-perl
#   liblist-allutils-perl liblist-moreutils-perl liblist-moreutils-xs-perl
#   liblist-someutils-perl liblist-someutils-xs-perl liblist-utilsby-perl
#   liblog-dispatch-perl liblog-log4perl-perl liblqr-1-0 liblwp-mediatypes-perl
#   liblwp-protocol-https-perl libmagick++-6.q16-8 libmagickcore-6.q16-6
#   libmagickcore-6.q16-6-extra libmagickwand-6.q16-6 libmail-sendmail-perl
#   libmailtools-perl libmd4c0 libmime-charset-perl libmime-lite-perl
#   libmime-types-perl libmodule-implementation-perl libmodule-runtime-perl
#   libmotif-common libmro-compat-perl libmtdev1 libnamespace-autoclean-perl
#   libnamespace-clean-perl libnet-http-perl libnet-smtp-ssl-perl
#   libnet-ssleay-perl libnetpbm10 libnumber-compare-perl libosp5 libostyle1c2
#   libpackage-stash-perl libpackage-stash-xs-perl libpadwalker-perl
#   libparams-classify-perl libparams-util-perl libparams-validate-perl
#   libparams-validationcompiler-perl libparse-recdescent-perl libpdfbox-java
#   libperlio-utf8-strict-perl libplot2c2 libpoppler-qt5-1 libpstoedit0c2a
#   libqt5core5a libqt5dbus5 libqt5gui5 libqt5network5 libqt5svg5 libqt5widgets5
#   libqt5xml5 libreadonly-perl libref-util-perl libref-util-xs-perl
#   libregexp-common-perl librole-tiny-perl libruby3.0 libscalar-list-utils-perl
#   libsombok3 libsort-key-perl libspecio-perl libstring-crc32-perl
#   libsub-exporter-perl libsub-exporter-progressive-perl libsub-identify-perl
#   libsub-install-perl libsub-name-perl libsub-quote-perl
#   libsys-hostname-long-perl libtext-bibtex-perl libtext-csv-perl
#   libtext-csv-xs-perl libtext-glob-perl libtext-roman-perl
#   libtext-unidecode-perl libtie-cycle-perl libtry-tiny-perl
#   libtypes-serialiser-perl libunicode-linebreak-perl liburi-perl
#   libvariable-magic-perl libwacom-bin libwacom-common libwacom9
#   libwmflite-0.2-7 libwww-perl libwww-robotrules-perl libxcb-icccm4
#   libxcb-image0 libxcb-keysyms1 libxcb-render-util0 libxcb-util1
#   libxcb-xinerama0 libxcb-xinput0 libxcb-xkb1 libxkbcommon-x11-0 libxm4
#   libxml-libxml-perl libxml-libxml-simple-perl libxml-libxslt-perl
#   libxml-namespacesupport-perl libxml-parser-perl libxml-sax-base-perl
#   libxml-sax-expat-perl libxml-sax-perl libxml-writer-perl libxstring-perl
#   libxtst6 libxxf86dga1 libyaml-tiny-perl libzip4 netbase netpbm openjade
#   perl-openssl-defaults pfb2t1c2pfb poppler-utils prerex preview-latex-style
#   ps2eps pstoedit psutils purifyeps qt5-gtk-platformtheme qttranslations5-l10n
#   rake ruby ruby-net-telnet ruby-rubygems ruby-webrick ruby-xmlrpc ruby3.0
#   rubygems-integration sgml-base teckit tex-gyre texinfo texlive-bibtex-extra
#   texlive-extra-utils texlive-font-utils texlive-fonts-extra
#   texlive-fonts-extra-doc texlive-fonts-extra-links texlive-fonts-recommended
#   texlive-fonts-recommended-doc texlive-formats-extra texlive-games
#   texlive-humanities texlive-humanities-doc texlive-lang-arabic
#   texlive-lang-chinese texlive-lang-cjk texlive-lang-cyrillic
#   texlive-lang-czechslovak texlive-lang-english texlive-lang-european
#   texlive-lang-french texlive-lang-german texlive-lang-greek
#   texlive-lang-italian texlive-lang-japanese texlive-lang-korean
#   texlive-lang-other texlive-lang-polish texlive-lang-portuguese
#   texlive-lang-spanish texlive-latex-base-doc texlive-latex-extra
#   texlive-latex-extra-doc texlive-latex-recommended
#   texlive-latex-recommended-doc texlive-luatex texlive-metapost
#   texlive-metapost-doc texlive-music texlive-pictures texlive-pictures-doc
#   texlive-plain-generic texlive-pstricks texlive-pstricks-doc
#   texlive-publishers texlive-publishers-doc texlive-science
#   texlive-science-doc texlive-xetex tipa vprerex x11-utils xbitmaps xpdf xterm
# Suggested packages:
#   asymptote-x11 perl-tk fontforge context-nonfree cups inetutils-inetd
#   | inet-superserver update-inetd smbclient ghostscript-x imagemagick-doc
#   autotrace enscript gimp gnuplot grads hp2xx html2ps libwmf-bin mplayer
#   povray radiance sane-utils transfig ufraw-batch auctex hbf-cns40-b5
#   hbf-jfs56 hbf-kanji48 libdigest-hmac-perl libgssapi-perl libgd-barcode-perl
#   libavalon-framework-java libcommons-logging-java-doc
#   libexcalibur-logkit-java liblog4j1.2-java libscalar-properties-perl
#   libfftw3-bin libfftw3-dev gsl-ref-psdoc | gsl-doc-pdf | gsl-doc-info
#   | gsl-ref-html libdbd-csv-perl liblog-dispatch-filerotate-perl librrds-perl
#   libxml-dom-perl libcrypt-ssleay-perl inkscape libpod2-base-perl default-mta
#   | mail-transport-agent libmojolicious-perl libscalar-number-perl
#   qt5-image-formats-plugins qtwayland5 libtest-fatal-perl libauthen-ntlm-perl
#   libxml-sax-expatxs-perl doc-base sgml-data xfig | ivtools-bin | tgif
#   | transfig ri ruby-dev bundler sgml-base-doc default-jre-headless xindy
#   python3-pygments icc-profiles libspreadsheet-parseexcel-perl dot2tex
#   tipa-doc mesa-utils xfonts-cyrillic
# Recommended packages:
#   fonts-freefont
# The following NEW packages will be installed:
#   aglfn asymptote asymptote-doc biber chktex cm-super cm-super-minimal context
#   context-modules cups-bsd cups-client cups-common dvidvi dvipng feynmf
#   fonts-adf-accanthis fonts-adf-berenis fonts-adf-gillius
#   fonts-adf-universalis fonts-arphic-bkai00mp fonts-arphic-bsmi00lp
#   fonts-arphic-gbsn00lp fonts-arphic-gkai00mp fonts-arphic-uming fonts-baekmuk
#   fonts-cabin fonts-cantarell fonts-comfortaa fonts-croscore
#   fonts-crosextra-caladea fonts-crosextra-carlito fonts-dejavu-core
#   fonts-dejavu-extra fonts-ebgaramond fonts-ebgaramond-extra
#   fonts-font-awesome fonts-freefont-otf fonts-freefont-ttf fonts-gfs-artemisia
#   fonts-gfs-baskerville fonts-gfs-bodoni-classic fonts-gfs-complutum
#   fonts-gfs-didot fonts-gfs-didot-classic fonts-gfs-gazis
#   fonts-gfs-neohellenic fonts-gfs-olga fonts-gfs-porson fonts-gfs-solomos
#   fonts-gfs-theokritos fonts-go fonts-hosny-amiri fonts-ipaexfont-gothic
#   fonts-ipaexfont-mincho fonts-ipafont-gothic fonts-ipafont-mincho
#   fonts-junicode fonts-lato fonts-linuxlibertine fonts-lobster
#   fonts-lobstertwo fonts-noto-color-emoji fonts-noto-core
#   fonts-oflb-asana-math fonts-open-sans fonts-roboto-unhinted fonts-sil-charis
#   fonts-sil-gentium fonts-sil-gentium-basic fonts-sil-gentiumplus
#   fonts-sil-gentiumplus-compact fonts-sil-padauk fonts-stix fonts-texgyre
#   fonts-tlwg-garuda fonts-tlwg-garuda-otf fonts-tlwg-kinnari
#   fonts-tlwg-kinnari-otf fonts-tlwg-laksaman fonts-tlwg-laksaman-otf
#   fonts-tlwg-loma fonts-tlwg-loma-otf fonts-tlwg-mono fonts-tlwg-mono-otf
#   fonts-tlwg-norasi fonts-tlwg-norasi-otf fonts-tlwg-purisa
#   fonts-tlwg-purisa-otf fonts-tlwg-sawasdee fonts-tlwg-sawasdee-otf
#   fonts-tlwg-typewriter fonts-tlwg-typewriter-otf fonts-tlwg-typist
#   fonts-tlwg-typist-otf fonts-tlwg-typo fonts-tlwg-typo-otf fonts-tlwg-umpush
#   fonts-tlwg-umpush-otf fonts-tlwg-waree fonts-tlwg-waree-otf
#   fonts-unfonts-core fonts-unfonts-extra fragmaster freeglut3 ghostscript
#   gsfonts gsfonts-x11 imagemagick imagemagick-6-common imagemagick-6.q16 info
#   install-info lacheck latex-cjk-all latex-cjk-chinese
#   latex-cjk-chinese-arphic-bkai00mp latex-cjk-chinese-arphic-bsmi00lp
#   latex-cjk-chinese-arphic-gbsn00lp latex-cjk-chinese-arphic-gkai00mp
#   latex-cjk-common latex-cjk-japanese latex-cjk-japanese-wadalab
#   latex-cjk-korean latex-cjk-thai latexdiff latexmk lcdf-typetools
#   libalgorithm-c3-perl libapache-pom-java libauthen-sasl-perl
#   libautovivification-perl libb-hooks-endofscope-perl libb-hooks-op-check-perl
#   libbtparse2 libbusiness-isbn-data-perl libbusiness-isbn-perl
#   libbusiness-ismn-perl libbusiness-issn-perl libclass-accessor-perl
#   libclass-c3-perl libclass-c3-xs-perl libclass-data-inheritable-perl
#   libclass-inspector-perl libclass-method-modifiers-perl
#   libclass-singleton-perl libclass-xsaccessor-perl libclone-perl
#   libcommon-sense-perl libcommons-logging-java libcommons-parent-java
#   libdata-compare-perl libdata-dump-perl libdata-optlist-perl
#   libdata-uniqid-perl libdate-simple-perl libdatetime-calendar-julian-perl
#   libdatetime-format-builder-perl libdatetime-format-strptime-perl
#   libdatetime-locale-perl libdatetime-perl libdatetime-timezone-perl
#   libdevel-callchecker-perl libdevel-caller-perl
#   libdevel-globaldestruction-perl libdevel-lexalias-perl
#   libdevel-stacktrace-perl libdist-checkconflicts-perl libdjvulibre-text
#   libdjvulibre21 libdynaloader-functions-perl libemail-date-format-perl
#   libemf1 libencode-eucjpms-perl libencode-hanextra-perl libencode-jis2k-perl
#   libencode-locale-perl libencode-perl libeval-closure-perl libevdev2
#   libexception-class-perl libexporter-tiny-perl libfftw3-double3
#   libfile-find-rule-perl libfile-homedir-perl libfile-listing-perl
#   libfile-sharedir-perl libfile-slurper-perl libfile-which-perl
#   libfont-afm-perl libfontbox-java libgsl27 libgslcblas0 libgudev-1.0-0
#   libhtml-form-perl libhtml-format-perl libhtml-parser-perl
#   libhtml-tagset-perl libhtml-tree-perl libhttp-cookies-perl
#   libhttp-daemon-perl libhttp-date-perl libhttp-message-perl
#   libhttp-negotiate-perl libinput-bin libinput10 libio-html-perl
#   libio-socket-ssl-perl libipc-run3-perl libipc-shareable-perl libjson-perl
#   libjson-xs-perl libjxr-tools libjxr0 liblingua-translit-perl
#   liblist-allutils-perl liblist-moreutils-perl liblist-moreutils-xs-perl
#   liblist-someutils-perl liblist-someutils-xs-perl liblist-utilsby-perl
#   liblog-dispatch-perl liblog-log4perl-perl liblqr-1-0 liblwp-mediatypes-perl
#   liblwp-protocol-https-perl libmagick++-6.q16-8 libmagickcore-6.q16-6
#   libmagickcore-6.q16-6-extra libmagickwand-6.q16-6 libmail-sendmail-perl
#   libmailtools-perl libmd4c0 libmime-charset-perl libmime-lite-perl
#   libmime-types-perl libmodule-implementation-perl libmodule-runtime-perl
#   libmotif-common libmro-compat-perl libmtdev1 libnamespace-autoclean-perl
#   libnamespace-clean-perl libnet-http-perl libnet-smtp-ssl-perl
#   libnet-ssleay-perl libnetpbm10 libnumber-compare-perl libosp5 libostyle1c2
#   libpackage-stash-perl libpackage-stash-xs-perl libpadwalker-perl
#   libparams-classify-perl libparams-util-perl libparams-validate-perl
#   libparams-validationcompiler-perl libparse-recdescent-perl libpdfbox-java
#   libperlio-utf8-strict-perl libplot2c2 libpoppler-qt5-1 libpstoedit0c2a
#   libqt5core5a libqt5dbus5 libqt5gui5 libqt5network5 libqt5svg5 libqt5widgets5
#   libqt5xml5 libreadonly-perl libref-util-perl libref-util-xs-perl
#   libregexp-common-perl librole-tiny-perl libruby3.0 libscalar-list-utils-perl
#   libsombok3 libsort-key-perl libspecio-perl libstring-crc32-perl
#   libsub-exporter-perl libsub-exporter-progressive-perl libsub-identify-perl
#   libsub-install-perl libsub-name-perl libsub-quote-perl
#   libsys-hostname-long-perl libtext-bibtex-perl libtext-csv-perl
#   libtext-csv-xs-perl libtext-glob-perl libtext-roman-perl
#   libtext-unidecode-perl libtie-cycle-perl libtry-tiny-perl
#   libtypes-serialiser-perl libunicode-linebreak-perl liburi-perl
#   libvariable-magic-perl libwacom-bin libwacom-common libwacom9
#   libwmflite-0.2-7 libwww-perl libwww-robotrules-perl libxcb-icccm4
#   libxcb-image0 libxcb-keysyms1 libxcb-render-util0 libxcb-util1
#   libxcb-xinerama0 libxcb-xinput0 libxcb-xkb1 libxkbcommon-x11-0 libxm4
#   libxml-libxml-perl libxml-libxml-simple-perl libxml-libxslt-perl
#   libxml-namespacesupport-perl libxml-parser-perl libxml-sax-base-perl
#   libxml-sax-expat-perl libxml-sax-perl libxml-writer-perl libxstring-perl
#   libxtst6 libxxf86dga1 libyaml-tiny-perl libzip4 netbase netpbm openjade
#   perl-openssl-defaults pfb2t1c2pfb poppler-utils prerex preview-latex-style
#   ps2eps pstoedit psutils purifyeps qt5-gtk-platformtheme qttranslations5-l10n
#   rake ruby ruby-net-telnet ruby-rubygems ruby-webrick ruby-xmlrpc ruby3.0
#   rubygems-integration sgml-base teckit tex-gyre texinfo texlive-bibtex-extra
#   texlive-extra-utils texlive-font-utils texlive-fonts-extra
#   texlive-fonts-extra-doc texlive-fonts-extra-links texlive-fonts-recommended
#   texlive-fonts-recommended-doc texlive-formats-extra texlive-full
#   texlive-games texlive-humanities texlive-humanities-doc texlive-lang-arabic
#   texlive-lang-chinese texlive-lang-cjk texlive-lang-cyrillic
#   texlive-lang-czechslovak texlive-lang-english texlive-lang-european
#   texlive-lang-french texlive-lang-german texlive-lang-greek
#   texlive-lang-italian texlive-lang-japanese texlive-lang-korean
#   texlive-lang-other texlive-lang-polish texlive-lang-portuguese
#   texlive-lang-spanish texlive-latex-base-doc texlive-latex-extra
#   texlive-latex-extra-doc texlive-latex-recommended
#   texlive-latex-recommended-doc texlive-luatex texlive-metapost
#   texlive-metapost-doc texlive-music texlive-pictures texlive-pictures-doc
#   texlive-plain-generic texlive-pstricks texlive-pstricks-doc
#   texlive-publishers texlive-publishers-doc texlive-science
#   texlive-science-doc texlive-xetex tipa vprerex x11-utils xbitmaps xpdf xterm
# 0 upgraded, 410 newly installed, 0 to remove and 30 not upgraded.
# Need to get 3,496 MB of archives.
# After this operation, 6,387 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/main amd64 install-info amd64 6.8-4build1 [88.1 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/universe amd64 fonts-arphic-bkai00mp all 2.10-21 [4,953 kB]
# Get:3 http://archive.ubuntu.com/ubuntu jammy/universe amd64 fonts-arphic-bsmi00lp all 2.10-18 [3,831 kB]
# Get:4 http://archive.ubuntu.com/ubuntu jammy/main amd64 fonts-arphic-uming all 0.2.20080216.2-10ubuntu2 [7,933 kB]
# Get:5 http://archive.ubuntu.com/ubuntu jammy/universe amd64 fonts-ipafont-gothic all 00303-21ubuntu1 [3,513 kB]
# Get:6 http://archive.ubuntu.com/ubuntu jammy/universe amd64 fonts-ipafont-mincho all 00303-21ubuntu1 [4,724 kB]
# Get:7 http://archive.ubuntu.com/ubuntu jammy/main amd64 fonts-lato all 2.0-2.1 [2,696 kB]
# Get:8 http://archive.ubuntu.com/ubuntu jammy/universe amd64 fonts-unfonts-core all 1:1.0.2-080608-16 [14.9 MB]
# Get:9 http://archive.ubuntu.com/ubuntu jammy/universe amd64 fonts-unfonts-extra all 1:1.0.2-080608+dfsg-9 [6,570 kB]
# Get:10 http://archive.ubuntu.com/ubuntu jammy/main amd64 libfftw3-double3 amd64 3.3.8-2ubuntu8 [770 kB]
# Get:11 http://archive.ubuntu.com/ubuntu jammy/universe amd64 liblqr-1-0 amd64 0.4.2-2.1 [27.7 kB]
# Get:12 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 imagemagick-6-common all 8:6.9.11.60+dfsg-1.3ubuntu0.22.04.5 [64.3 kB]
# Get:13 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libmagickcore-6.q16-6 amd64 8:6.9.11.60+dfsg-1.3ubuntu0.22.04.5 [1,795 kB]
# Get:14 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libmagickwand-6.q16-6 amd64 8:6.9.11.60+dfsg-1.3ubuntu0.22.04.5 [328 kB]
# Get:15 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libmotif-common all 2.3.8-3 [11.0 kB]
# Get:16 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libqt5core5a amd64 5.15.3+dfsg-2ubuntu0.2 [2,006 kB]
# Get:17 http://archive.ubuntu.com/ubuntu jammy/main amd64 libevdev2 amd64 1.12.1+dfsg-1 [39.5 kB]
# Get:18 http://archive.ubuntu.com/ubuntu jammy/main amd64 libmtdev1 amd64 1.1.6-1build4 [14.5 kB]
# Get:19 http://archive.ubuntu.com/ubuntu jammy/main amd64 libgudev-1.0-0 amd64 1:237-2build1 [16.3 kB]
# Get:20 http://archive.ubuntu.com/ubuntu jammy/main amd64 libwacom-common all 2.2.0-1 [54.3 kB]
# Get:21 http://archive.ubuntu.com/ubuntu jammy/main amd64 libwacom9 amd64 2.2.0-1 [22.0 kB]
# Get:22 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libinput-bin amd64 1.20.0-1ubuntu0.3 [19.9 kB]
# Get:23 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libinput10 amd64 1.20.0-1ubuntu0.3 [131 kB]
# Get:24 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libmd4c0 amd64 0.4.8-1 [42.0 kB]
# Get:25 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libqt5dbus5 amd64 5.15.3+dfsg-2ubuntu0.2 [222 kB]
# Get:26 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libqt5network5 amd64 5.15.3+dfsg-2ubuntu0.2 [731 kB]
# Get:27 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcb-icccm4 amd64 0.4.1-1.1build2 [11.5 kB]
# Get:28 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcb-util1 amd64 0.4.0-1build2 [11.4 kB]
# Get:29 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcb-image0 amd64 0.4.0-2 [11.5 kB]
# Get:30 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcb-keysyms1 amd64 0.4.0-1build3 [8,746 B]
# Get:31 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcb-render-util0 amd64 0.3.9-1build3 [10.3 kB]
# Get:32 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcb-xinerama0 amd64 1.14-3ubuntu3 [5,414 B]
# Get:33 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcb-xinput0 amd64 1.14-3ubuntu3 [34.3 kB]
# Get:34 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcb-xkb1 amd64 1.14-3ubuntu3 [32.8 kB]
# Get:35 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxkbcommon-x11-0 amd64 1.4.0-1 [14.4 kB]
# Get:36 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libqt5gui5 amd64 5.15.3+dfsg-2ubuntu0.2 [3,722 kB]
# Get:37 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libqt5widgets5 amd64 5.15.3+dfsg-2ubuntu0.2 [2,561 kB]
# Get:38 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libqt5svg5 amd64 5.15.3-1 [149 kB]
# Get:39 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libxm4 amd64 2.3.8-3 [1,001 kB]
# Get:40 http://archive.ubuntu.com/ubuntu jammy/main amd64 sgml-base all 1.30 [12.5 kB]
# Get:41 http://archive.ubuntu.com/ubuntu jammy/main amd64 netbase all 6.3 [12.9 kB]
# Get:42 http://archive.ubuntu.com/ubuntu jammy/main amd64 info amd64 6.8-4build1 [213 kB]
# Get:43 http://archive.ubuntu.com/ubuntu jammy/universe amd64 freeglut3 amd64 2.8.1-6 [74.0 kB]
# Get:44 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libgslcblas0 amd64 2.7.1+dfsg-3 [94.4 kB]
# Get:45 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libgsl27 amd64 2.7.1+dfsg-3 [1,000 kB]
# Get:46 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 ghostscript amd64 9.55.0~dfsg1-0ubuntu5.11 [49.4 kB]
# Get:47 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 imagemagick-6.q16 amd64 8:6.9.11.60+dfsg-1.3ubuntu0.22.04.5 [224 kB]
# Get:48 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 imagemagick amd64 8:6.9.11.60+dfsg-1.3ubuntu0.22.04.5 [14.6 kB]
# Get:49 http://archive.ubuntu.com/ubuntu jammy/universe amd64 texlive-latex-recommended all 2021.20220204-1 [14.4 MB]
# Get:50 http://archive.ubuntu.com/ubuntu jammy/universe amd64 texlive-pictures all 2021.20220204-1 [8,720 kB]
# Get:51 http://archive.ubuntu.com/ubuntu jammy/universe amd64 texlive-plain-generic all 2021.20220204-1 [27.5 MB]
# Get:52 http://archive.ubuntu.com/ubuntu jammy/universe amd64 texlive-pstricks all 2021.20220204-1 [26.6 MB]
# Get:53 http://archive.ubuntu.com/ubuntu jammy/universe amd64 asymptote amd64 2.78+ds-2 [1,852 kB]
# Get:54 http://archive.ubuntu.com/ubuntu jammy/universe amd64 asymptote-doc all 2.78+ds-2 [2,967 kB]
# Get:55 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libautovivification-perl amd64 0.18-1build4 [22.6 kB]
# Get:56 http://archive.ubuntu.com/ubuntu jammy/main amd64 libsub-name-perl amd64 0.26-1build3 [11.4 kB]
# Get:57 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libclass-accessor-perl all 0.51-1 [21.2 kB]
# Get:58 http://archive.ubuntu.com/ubuntu jammy/main amd64 libclone-perl amd64 0.45-1build3 [11.0 kB]
# Get:59 http://archive.ubuntu.com/ubuntu jammy/main amd64 libnumber-compare-perl all 0.03-2 [7,058 B]
# Get:60 http://archive.ubuntu.com/ubuntu jammy/main amd64 libtext-glob-perl all 0.11-2 [8,042 B]
# Get:61 http://archive.ubuntu.com/ubuntu jammy/main amd64 libfile-find-rule-perl all 0.34-1 [28.3 kB]
# Get:62 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libdata-compare-perl all 1.27-1 [18.4 kB]
# Get:63 http://archive.ubuntu.com/ubuntu jammy/main amd64 libdata-dump-perl all 1.25-1 [25.9 kB]
# Get:64 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libdata-uniqid-perl all 0.12-1.1 [4,732 B]
# Get:65 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libdate-simple-perl amd64 3.0300-3build2 [34.1 kB]
# Get:66 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libclass-inspector-perl all 1.36-1 [16.3 kB]
# Get:67 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libfile-sharedir-perl all 1.118-1 [15.0 kB]
# Get:68 http://archive.ubuntu.com/ubuntu jammy/main amd64 libb-hooks-op-check-perl amd64 0.22-1build5 [10.3 kB]
# Get:69 http://archive.ubuntu.com/ubuntu jammy/main amd64 libdynaloader-functions-perl all 0.003-1.1 [12.1 kB]
# Get:70 http://archive.ubuntu.com/ubuntu jammy/main amd64 libdevel-callchecker-perl amd64 0.008-1ubuntu4 [14.9 kB]
# Get:71 http://archive.ubuntu.com/ubuntu jammy/main amd64 libparams-classify-perl amd64 0.015-1build5 [22.0 kB]
# Get:72 http://archive.ubuntu.com/ubuntu jammy/main amd64 libmodule-runtime-perl all 0.016-1 [16.2 kB]
# Get:73 http://archive.ubuntu.com/ubuntu jammy/main amd64 libtry-tiny-perl all 0.31-1 [21.8 kB]
# Get:74 http://archive.ubuntu.com/ubuntu jammy/main amd64 libmodule-implementation-perl all 0.09-1.1 [11.6 kB]
# Get:75 http://archive.ubuntu.com/ubuntu jammy/main amd64 libsub-exporter-progressive-perl all 0.001013-1 [6,784 B]
# Get:76 http://archive.ubuntu.com/ubuntu jammy/main amd64 libvariable-magic-perl amd64 0.62-1build5 [35.9 kB]
# Get:77 http://archive.ubuntu.com/ubuntu jammy/main amd64 libb-hooks-endofscope-perl all 0.25-1 [17.8 kB]
# Get:78 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libscalar-list-utils-perl amd64 1:1.61-1 [56.9 kB]
# Get:79 http://archive.ubuntu.com/ubuntu jammy/main amd64 libpackage-stash-perl all 0.39-1 [19.1 kB]
# Get:80 http://archive.ubuntu.com/ubuntu jammy/main amd64 libsub-identify-perl amd64 0.14-1build5 [10.4 kB]
# Get:81 http://archive.ubuntu.com/ubuntu jammy/main amd64 libnamespace-clean-perl all 0.27-1 [13.6 kB]
# Get:82 http://archive.ubuntu.com/ubuntu jammy/main amd64 libnamespace-autoclean-perl all 0.29-1 [12.5 kB]
# Get:83 http://archive.ubuntu.com/ubuntu jammy/main amd64 libparams-util-perl amd64 1.102-1build3 [22.7 kB]
# Get:84 http://archive.ubuntu.com/ubuntu jammy/main amd64 libsub-install-perl all 0.928-1.1 [9,972 B]
# Get:85 http://archive.ubuntu.com/ubuntu jammy/main amd64 libdata-optlist-perl all 0.112-1 [11.0 kB]
# Get:86 http://archive.ubuntu.com/ubuntu jammy/main amd64 libsub-exporter-perl all 0.988-1 [50.6 kB]
# Get:87 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libeval-closure-perl all 0.14-1 [10.3 kB]
# Get:88 http://archive.ubuntu.com/ubuntu jammy/main amd64 libclass-data-inheritable-perl all 0.08-3 [8,084 B]
# Get:89 http://archive.ubuntu.com/ubuntu jammy/main amd64 libdevel-stacktrace-perl all 2.0400-1 [22.7 kB]
# Get:90 http://archive.ubuntu.com/ubuntu jammy/main amd64 libexception-class-perl all 1.45-1 [28.6 kB]
# Get:91 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libparams-validationcompiler-perl all 0.30-1 [28.9 kB]
# Get:92 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libalgorithm-c3-perl all 0.11-1 [11.0 kB]
# Get:93 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libclass-c3-perl all 0.35-1 [19.0 kB]
# Get:94 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libmro-compat-perl all 0.15-1 [11.7 kB]
# Get:95 http://archive.ubuntu.com/ubuntu jammy/main amd64 libclass-method-modifiers-perl all 2.13-1 [16.2 kB]
# Get:96 http://archive.ubuntu.com/ubuntu jammy/main amd64 librole-tiny-perl all 2.002004-1 [16.3 kB]
# Get:97 http://archive.ubuntu.com/ubuntu jammy/main amd64 libsub-quote-perl all 2.006006-1 [19.5 kB]
# Get:98 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libxstring-perl amd64 0.005-1build2 [8,076 B]
# Get:99 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libspecio-perl all 0.47-1 [140 kB]
# Get:100 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libdatetime-locale-perl all 1:1.33-1 [2,733 kB]
# Get:101 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libclass-singleton-perl all 1.6-1 [12.4 kB]
# Get:102 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libdatetime-timezone-perl all 1:2.51-1+2021e [273 kB]
# Get:103 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libdatetime-perl amd64 2:1.55-1build1 [97.4 kB]
# Get:104 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libdatetime-format-strptime-perl all 1.7900-1 [29.7 kB]
# Get:105 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libparams-validate-perl amd64 1.30-1build3 [54.7 kB]
# Get:106 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libdatetime-format-builder-perl all 0.8300-1 [61.5 kB]
# Get:107 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libdatetime-calendar-julian-perl all 0.107-1 [8,628 B]
# Get:108 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libencode-eucjpms-perl amd64 0.07-3build9 [205 kB]
# Get:109 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libencode-hanextra-perl amd64 0.23-5build4 [2,177 kB]
# Get:110 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libencode-jis2k-perl amd64 0.03-1build7 [403 kB]
# Get:111 http://archive.ubuntu.com/ubuntu jammy/main amd64 libfile-slurper-perl all 0.013-1 [8,040 B]
# Get:112 http://archive.ubuntu.com/ubuntu jammy/main amd64 libipc-run3-perl all 0.048-2 [31.4 kB]
# Get:113 http://archive.ubuntu.com/ubuntu jammy/main amd64 perl-openssl-defaults amd64 5build2 [7,542 B]
# Get:114 http://archive.ubuntu.com/ubuntu jammy/main amd64 libnet-ssleay-perl amd64 1.92-1build2 [327 kB]
# Get:115 http://archive.ubuntu.com/ubuntu jammy/main amd64 libio-socket-ssl-perl all 2.074-2 [192 kB]
# Get:116 http://archive.ubuntu.com/ubuntu jammy/main amd64 liburi-perl all 5.10-1 [78.8 kB]
# Get:117 http://archive.ubuntu.com/ubuntu jammy/main amd64 libnet-http-perl all 6.22-1 [23.2 kB]
# Get:118 http://archive.ubuntu.com/ubuntu jammy/main amd64 libencode-locale-perl all 1.05-1.1 [11.8 kB]
# Get:119 http://archive.ubuntu.com/ubuntu jammy/main amd64 libhttp-date-perl all 6.05-1 [9,920 B]
# Get:120 http://archive.ubuntu.com/ubuntu jammy/main amd64 libfile-listing-perl all 6.14-1 [11.2 kB]
# Get:121 http://archive.ubuntu.com/ubuntu jammy/main amd64 libhtml-tagset-perl all 3.20-4 [12.5 kB]
# Get:122 http://archive.ubuntu.com/ubuntu jammy/main amd64 libhtml-parser-perl amd64 3.76-1build2 [88.4 kB]
# Get:123 http://archive.ubuntu.com/ubuntu jammy/main amd64 libhtml-tree-perl all 5.07-2 [200 kB]
# Get:124 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libencode-perl amd64 3.16-1build1 [1,810 kB]
# Get:125 http://archive.ubuntu.com/ubuntu jammy/main amd64 libio-html-perl all 1.004-2 [15.4 kB]
# Get:126 http://archive.ubuntu.com/ubuntu jammy/main amd64 liblwp-mediatypes-perl all 6.04-1 [19.5 kB]
# Get:127 http://archive.ubuntu.com/ubuntu jammy/main amd64 libhttp-message-perl all 6.36-1 [76.8 kB]
# Get:128 http://archive.ubuntu.com/ubuntu jammy/main amd64 libhttp-cookies-perl all 6.10-1 [18.4 kB]
# Get:129 http://archive.ubuntu.com/ubuntu jammy/main amd64 libhttp-negotiate-perl all 6.01-1 [12.5 kB]
# Get:130 http://archive.ubuntu.com/ubuntu jammy/main amd64 libwww-robotrules-perl all 6.02-1 [12.6 kB]
# Get:131 http://archive.ubuntu.com/ubuntu jammy/main amd64 libwww-perl all 6.61-1 [141 kB]
# Get:132 http://archive.ubuntu.com/ubuntu jammy/main amd64 liblwp-protocol-https-perl all 6.10-1 [10.9 kB]
# Get:133 http://archive.ubuntu.com/ubuntu jammy/universe amd64 liblingua-translit-perl all 0.28-1 [24.9 kB]
# Get:134 http://archive.ubuntu.com/ubuntu jammy/main amd64 liblist-someutils-perl all 0.58-1 [29.7 kB]
# Get:135 http://archive.ubuntu.com/ubuntu jammy/main amd64 liblist-utilsby-perl all 0.11-1 [14.7 kB]
# Get:136 http://archive.ubuntu.com/ubuntu jammy/universe amd64 liblist-allutils-perl all 0.19-1 [41.5 kB]
# Get:137 http://archive.ubuntu.com/ubuntu jammy/main amd64 libexporter-tiny-perl all 1.002002-1 [36.2 kB]
# Get:138 http://archive.ubuntu.com/ubuntu jammy/main amd64 liblist-moreutils-xs-perl amd64 0.430-2build2 [41.9 kB]
# Get:139 http://archive.ubuntu.com/ubuntu jammy/main amd64 liblist-moreutils-perl all 0.430-2 [38.2 kB]
# Get:140 http://archive.ubuntu.com/ubuntu jammy/universe amd64 liblog-log4perl-perl all 1.54-1 [343 kB]
# Get:141 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libparse-recdescent-perl all 1.967015+dfsg-2 [145 kB]
# Get:142 http://archive.ubuntu.com/ubuntu jammy/main amd64 libreadonly-perl all 2.050-3 [19.9 kB]
# Get:143 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libregexp-common-perl all 2017060201-1 [168 kB]
# Get:144 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libsort-key-perl amd64 1.33-2build5 [36.8 kB]
# Get:145 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libbtparse2 amd64 0.88-3build3 [41.1 kB]
# Get:146 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libtext-bibtex-perl amd64 0.88-3build3 [132 kB]
# Get:147 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libtext-csv-perl all 2.01-1 [108 kB]
# Get:148 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libtext-csv-xs-perl amd64 1.47-1build1 [115 kB]
# Get:149 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libtext-roman-perl all 3.5-2.1 [12.2 kB]
# Get:150 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxml-namespacesupport-perl all 1.12-1.1 [13.2 kB]
# Get:151 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxml-sax-base-perl all 1.09-1.1 [19.0 kB]
# Get:152 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxml-sax-perl all 1.02+dfsg-3 [57.0 kB]
# Get:153 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxml-libxml-perl amd64 2.0207+dfsg+really+2.0134-1 [325 kB]
# Get:154 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libxml-libxml-simple-perl all 1.01-1 [24.6 kB]
# Get:155 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libxml-libxslt-perl amd64 1.99-1build2 [41.1 kB]
# Get:156 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libxml-writer-perl all 0.900-1 [25.1 kB]
# Get:157 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libbusiness-isbn-data-perl all 20210112.006-1 [20.1 kB]
# Get:158 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libbusiness-isbn-perl all 3.006-1 [23.8 kB]
# Get:159 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libtie-cycle-perl all 1.226-1 [10.8 kB]
# Get:160 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libbusiness-ismn-perl all 1.202-1 [14.1 kB]
# Get:161 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libbusiness-issn-perl all 1.005-1 [10.8 kB]
# Get:162 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libsombok3 amd64 2.4.0-2 [26.9 kB]
# Get:163 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libmime-charset-perl all 1.012.2-1 [30.9 kB]
# Get:164 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libunicode-linebreak-perl amd64 0.0.20190101-1build3 [99.1 kB]
# Get:165 http://archive.ubuntu.com/ubuntu jammy/universe amd64 biber all 2.17-2 [548 kB]
# Get:166 http://archive.ubuntu.com/ubuntu jammy/universe amd64 chktex amd64 1.7.6-4 [92.6 kB]
# Get:167 http://archive.ubuntu.com/ubuntu jammy/universe amd64 cm-super-minimal all 0.3.4-17 [5,777 kB]
# Get:168 http://archive.ubuntu.com/ubuntu jammy/universe amd64 pfb2t1c2pfb amd64 0.3-11 [9,342 B]
# Get:169 http://archive.ubuntu.com/ubuntu jammy/universe amd64 cm-super all 0.3.4-17 [20.2 MB]
# Get:170 http://archive.ubuntu.com/ubuntu jammy/main amd64 rubygems-integration all 1.18 [5,336 B]
# Get:171 http://archive.ubuntu.com/ubuntu jammy/main amd64 rake all 13.0.6-2 [61.7 kB]
# Get:172 http://archive.ubuntu.com/ubuntu jammy/main amd64 ruby-net-telnet all 0.1.1-2 [12.6 kB]
# Get:173 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 ruby-webrick all 1.7.0-3ubuntu0.1 [52.1 kB]
# Get:174 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 ruby-xmlrpc all 0.3.2-1ubuntu0.1 [24.9 kB]
# Get:175 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libruby3.0 amd64 3.0.2-7ubuntu2.10 [5,114 kB]
# Get:176 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 ruby3.0 amd64 3.0.2-7ubuntu2.10 [50.1 kB]
# Get:177 http://archive.ubuntu.com/ubuntu jammy/main amd64 ruby-rubygems all 3.3.5-2 [228 kB]
# Get:178 http://archive.ubuntu.com/ubuntu jammy/main amd64 ruby amd64 1:3.0~exp1 [5,100 B]
# Get:179 http://archive.ubuntu.com/ubuntu jammy/universe amd64 texlive-metapost all 2021.20220204-1 [453 kB]
# Get:180 http://archive.ubuntu.com/ubuntu jammy/universe amd64 tex-gyre all 20180621-3.1 [6,209 kB]
# Get:181 http://archive.ubuntu.com/ubuntu jammy/universe amd64 context all 2021.03.05.20220211-1 [103 MB]
# Get:182 http://archive.ubuntu.com/ubuntu jammy/universe amd64 context-modules all 20210301-1 [9,035 kB]
# Get:183 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 cups-common all 2.4.1op1-1ubuntu4.11 [253 kB]
# Get:184 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 cups-client amd64 2.4.1op1-1ubuntu4.11 [127 kB]
# Get:185 http://archive.ubuntu.com/ubuntu jammy/universe amd64 dvidvi amd64 1.0-8.2 [16.5 kB]
# Get:186 http://archive.ubuntu.com/ubuntu jammy/universe amd64 dvipng amd64 1.15-1.1 [78.9 kB]
# Get:187 http://archive.ubuntu.com/ubuntu jammy/universe amd64 texlive-font-utils all 2021.20220204-1 [4,097 kB]
# Get:188 http://archive.ubuntu.com/ubuntu jammy/universe amd64 texlive-luatex all 2021.20220204-1 [17.4 MB]
# Get:189 http://archive.ubuntu.com/ubuntu jammy/universe amd64 texlive-extra-utils all 2021.20220204-1 [52.0 MB]
# Get:190 http://archive.ubuntu.com/ubuntu jammy/universe amd64 feynmf all 1.08-13 [994 kB]
# Get:191 http://archive.ubuntu.com/ubuntu jammy/universe amd64 fonts-adf-accanthis all 0.20190904-2 [203 kB]
# Get:192 http://archive.ubuntu.com/ubuntu jammy/universe amd64 fonts-adf-berenis all 0.20190904-2 [313 kB]
# Get:193 http://archive.ubuntu.com/ubuntu jammy/universe amd64 fonts-adf-gillius all 0.20190904-2 [190 kB]
# Get:194 http://archive.ubuntu.com/ubuntu jammy/universe amd64 fonts-adf-universalis all 0.20190904-2 [112 kB]
# Get:195 http://archive.ubuntu.com/ubuntu jammy/universe amd64 fonts-arphic-gbsn00lp all 2.11-16 [1,724 kB]
# Get:196 http://archive.ubuntu.com/ubuntu jammy/universe amd64 fonts-arphic-gkai00mp all 2.11-16 [2,292 kB]
# Get:197 http://archive.ubuntu.com/ubuntu jammy/universe amd64 fonts-baekmuk all 2.2-13 [8,764 kB]
# Get:198 http://archive.ubuntu.com/ubuntu jammy/universe amd64 fonts-cabin all 1.5-3 [141 kB]
# Get:199 http://archive.ubuntu.com/ubuntu jammy/universe amd64 fonts-cantarell all 0.303-2 [286 kB]
# Get:200 http://archive.ubuntu.com/ubuntu jammy/universe amd64 fonts-comfortaa all 3.001-3 [129 kB]
# Get:201 http://archive.ubuntu.com/ubuntu jammy/universe amd64 fonts-croscore all 20201225-1build1 [1,572 kB]
# Get:202 http://archive.ubuntu.com/ubuntu jammy/universe amd64 fonts-crosextra-caladea all 20130214-2.1 [82.4 kB]
# Get:203 http://archive.ubuntu.com/ubuntu jammy/universe amd64 fonts-crosextra-carlito all 20130920-1.1 [743 kB]
# Get:204 http://archive.ubuntu.com/ubuntu jammy/main amd64 fonts-dejavu-core all 2.37-2build1 [1,041 kB]
# Get:205 http://archive.ubuntu.com/ubuntu jammy/main amd64 fonts-dejavu-extra all 2.37-2build1 [2,041 kB]
# Get:206 http://archive.ubuntu.com/ubuntu jammy/universe amd64 fonts-ebgaramond all 0.016+git20210310.42d4f9f2-1 [512 kB]
# Get:207 http://archive.ubuntu.com/ubuntu jammy/universe amd64 fonts-ebgaramond-extra all 0.016+git20210310.42d4f9f2-1 [2,233 kB]
# Get:208 http://archive.ubuntu.com/ubuntu jammy/main amd64 fonts-font-awesome all 5.0.10+really4.7.0~dfsg-4.1 [516 kB]
# Get:209 http://archive.ubuntu.com/ubuntu jammy/universe amd64 fonts-freefont-otf all 20120503-10build1 [3,054 kB]
# Get:210 http://archive.ubuntu.com/ubuntu jammy/main amd64 fonts-freefont-ttf all 20120503-10build1 [2,388 kB]
# Get:211 http://archive.ubuntu.com/ubuntu jammy/universe amd64 fonts-gfs-artemisia all 1.1-6 [260 kB]
# Get:212 http://archive.ubuntu.com/ubuntu jammy/universe amd64 fonts-gfs-baskerville all 1.1-6 [43.7 kB]
# Get:213 http://archive.ubuntu.com/ubuntu jammy/universe amd64 fonts-gfs-bodoni-classic all 1.1-6 [47.2 kB]
# Get:214 http://archive.ubuntu.com/ubuntu jammy/universe amd64 fonts-gfs-complutum all 1.1-7 [41.8 kB]
# Get:215 http://archive.ubuntu.com/ubuntu jammy/universe amd64 fonts-gfs-didot all 1.1-7 [278 kB]
# Get:216 http://archive.ubuntu.com/ubuntu jammy/universe amd64 fonts-gfs-didot-classic all 1.1-6 [45.1 kB]
# Get:217 http://archive.ubuntu.com/ubuntu jammy/universe amd64 fonts-gfs-gazis all 1.1-6 [46.5 kB]
# Get:218 http://archive.ubuntu.com/ubuntu jammy/universe amd64 fonts-gfs-neohellenic all 1.1-7 [215 kB]
# Get:219 http://archive.ubuntu.com/ubuntu jammy/universe amd64 fonts-gfs-olga all 1.1-6 [33.5 kB]
# Get:220 http://archive.ubuntu.com/ubuntu jammy/universe amd64 fonts-gfs-porson all 1.1-7 [33.9 kB]
# Get:221 http://archive.ubuntu.com/ubuntu jammy/universe amd64 fonts-gfs-solomos all 1.1-6 [40.9 kB]
# Get:222 http://archive.ubuntu.com/ubuntu jammy/universe amd64 fonts-gfs-theokritos all 1.1-6 [61.4 kB]
# Get:223 http://archive.ubuntu.com/ubuntu jammy/universe amd64 fonts-go all 0~20170330-1 [369 kB]
# Get:224 http://archive.ubuntu.com/ubuntu jammy/main amd64 fonts-hosny-amiri all 0.113-1 [591 kB]
# Get:225 http://archive.ubuntu.com/ubuntu jammy/universe amd64 fonts-ipaexfont-gothic all 00401-3ubuntu1 [3,341 kB]
# Get:226 http://archive.ubuntu.com/ubuntu jammy/universe amd64 fonts-ipaexfont-mincho all 00401-3ubuntu1 [4,604 kB]
# Get:227 http://archive.ubuntu.com/ubuntu jammy/universe amd64 fonts-junicode all 1.002-2 [828 kB]
# Get:228 http://archive.ubuntu.com/ubuntu jammy/universe amd64 fonts-linuxlibertine all 5.3.0-6 [1,627 kB]
# Get:229 http://archive.ubuntu.com/ubuntu jammy/universe amd64 fonts-lobster all 2.0-2.1 [38.9 kB]
# Get:230 http://archive.ubuntu.com/ubuntu jammy/universe amd64 fonts-lobstertwo all 2.0-2.1 [93.3 kB]
# Get:231 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 fonts-noto-color-emoji all 2.047-0ubuntu0.22.04.1 [10.0 MB]
# Get:232 http://archive.ubuntu.com/ubuntu jammy/main amd64 fonts-noto-core all 20201225-1build1 [12.2 MB]
# Get:233 http://archive.ubuntu.com/ubuntu jammy/universe amd64 fonts-oflb-asana-math all 000.907-7build1 [245 kB]
# Get:234 http://archive.ubuntu.com/ubuntu jammy/universe amd64 fonts-open-sans all 1.11-2 [635 kB]
# Get:235 http://archive.ubuntu.com/ubuntu jammy/universe amd64 fonts-roboto-unhinted all 2:0~20170802-3 [2,376 kB]
# Get:236 http://archive.ubuntu.com/ubuntu jammy/universe amd64 fonts-sil-charis all 6.101-1 [3,973 kB]
# Get:237 http://archive.ubuntu.com/ubuntu jammy/universe amd64 fonts-sil-gentium all 20081126:1.03-4 [245 kB]
# Get:238 http://archive.ubuntu.com/ubuntu jammy/universe amd64 fonts-sil-gentium-basic all 1.102-1.1 [384 kB]
# Get:239 http://archive.ubuntu.com/ubuntu jammy/universe amd64 fonts-sil-gentiumplus all 6.101-1 [8,086 kB]
# Get:240 http://archive.ubuntu.com/ubuntu jammy/universe amd64 fonts-sil-gentiumplus-compact all 5.000-4 [1,514 kB]
# Get:241 http://archive.ubuntu.com/ubuntu jammy/main amd64 fonts-sil-padauk all 5.000-3 [1,439 kB]
# Get:242 http://archive.ubuntu.com/ubuntu jammy/universe amd64 fonts-texgyre all 20180621-3.1 [10.2 MB]
# Get:243 http://archive.ubuntu.com/ubuntu jammy/universe amd64 fonts-tlwg-garuda-otf all 1:0.7.3-1 [113 kB]
# Get:244 http://archive.ubuntu.com/ubuntu jammy/main amd64 fonts-tlwg-garuda all 1:0.7.3-1 [4,360 B]
# Get:245 http://archive.ubuntu.com/ubuntu jammy/universe amd64 fonts-tlwg-kinnari-otf all 1:0.7.3-1 [187 kB]
# Get:246 http://archive.ubuntu.com/ubuntu jammy/main amd64 fonts-tlwg-kinnari all 1:0.7.3-1 [4,362 B]
# Get:247 http://archive.ubuntu.com/ubuntu jammy/universe amd64 fonts-tlwg-laksaman-otf all 1:0.7.3-1 [139 kB]
# Get:248 http://archive.ubuntu.com/ubuntu jammy/main amd64 fonts-tlwg-laksaman all 1:0.7.3-1 [4,346 B]
# Get:249 http://archive.ubuntu.com/ubuntu jammy/universe amd64 fonts-tlwg-loma-otf all 1:0.7.3-1 [107 kB]
# Get:250 http://archive.ubuntu.com/ubuntu jammy/main amd64 fonts-tlwg-loma all 1:0.7.3-1 [4,102 B]
# Get:251 http://archive.ubuntu.com/ubuntu jammy/universe amd64 fonts-tlwg-mono-otf all 1:0.7.3-1 [101 kB]
# Get:252 http://archive.ubuntu.com/ubuntu jammy/main amd64 fonts-tlwg-mono all 1:0.7.3-1 [4,072 B]
# Get:253 http://archive.ubuntu.com/ubuntu jammy/universe amd64 fonts-tlwg-norasi-otf all 1:0.7.3-1 [219 kB]
# Get:254 http://archive.ubuntu.com/ubuntu jammy/main amd64 fonts-tlwg-norasi all 1:0.7.3-1 [4,082 B]
# Get:255 http://archive.ubuntu.com/ubuntu jammy/universe amd64 fonts-tlwg-purisa-otf all 1:0.7.3-1 [208 kB]
# Get:256 http://archive.ubuntu.com/ubuntu jammy/main amd64 fonts-tlwg-purisa all 1:0.7.3-1 [3,556 B]
# Get:257 http://archive.ubuntu.com/ubuntu jammy/universe amd64 fonts-tlwg-sawasdee-otf all 1:0.7.3-1 [101 kB]
# Get:258 http://archive.ubuntu.com/ubuntu jammy/main amd64 fonts-tlwg-sawasdee all 1:0.7.3-1 [3,574 B]
# Get:259 http://archive.ubuntu.com/ubuntu jammy/universe amd64 fonts-tlwg-typewriter-otf all 1:0.7.3-1 [105 kB]
# Get:260 http://archive.ubuntu.com/ubuntu jammy/main amd64 fonts-tlwg-typewriter all 1:0.7.3-1 [3,630 B]
# Get:261 http://archive.ubuntu.com/ubuntu jammy/universe amd64 fonts-tlwg-typist-otf all 1:0.7.3-1 [108 kB]
# Get:262 http://archive.ubuntu.com/ubuntu jammy/main amd64 fonts-tlwg-typist all 1:0.7.3-1 [4,066 B]
# Get:263 http://archive.ubuntu.com/ubuntu jammy/universe amd64 fonts-tlwg-typo-otf all 1:0.7.3-1 [109 kB]
# Get:264 http://archive.ubuntu.com/ubuntu jammy/main amd64 fonts-tlwg-typo all 1:0.7.3-1 [4,106 B]
# Get:265 http://archive.ubuntu.com/ubuntu jammy/universe amd64 fonts-tlwg-umpush-otf all 1:0.7.3-1 [146 kB]
# Get:266 http://archive.ubuntu.com/ubuntu jammy/main amd64 fonts-tlwg-umpush all 1:0.7.3-1 [4,340 B]
# Get:267 http://archive.ubuntu.com/ubuntu jammy/universe amd64 fonts-tlwg-waree-otf all 1:0.7.3-1 [117 kB]
# Get:268 http://archive.ubuntu.com/ubuntu jammy/main amd64 fonts-tlwg-waree all 1:0.7.3-1 [4,092 B]
# Get:269 http://archive.ubuntu.com/ubuntu jammy/universe amd64 gsfonts all 1:8.11+urwcyr1.0.7~pre44-4.5 [3,120 kB]
# Get:270 http://archive.ubuntu.com/ubuntu jammy/universe amd64 gsfonts-x11 all 0.28 [7,356 B]
# Get:271 http://archive.ubuntu.com/ubuntu jammy/universe amd64 lacheck amd64 1.26-17 [27.6 kB]
# Get:272 http://archive.ubuntu.com/ubuntu jammy/universe amd64 latex-cjk-common amd64 4.8.4+git20170127-4 [206 kB]
# Get:273 http://archive.ubuntu.com/ubuntu jammy/universe amd64 latex-cjk-chinese amd64 4.8.4+git20170127-4 [58.5 kB]
# Get:274 http://archive.ubuntu.com/ubuntu jammy/universe amd64 latex-cjk-japanese amd64 4.8.4+git20170127-4 [37.1 kB]
# Get:275 http://archive.ubuntu.com/ubuntu jammy/universe amd64 latex-cjk-korean all 4.8.4+git20170127-4 [16.7 kB]
# Get:276 http://archive.ubuntu.com/ubuntu jammy/universe amd64 texlive-lang-other all 2021.20220204-1 [33.9 MB]
# Get:277 http://archive.ubuntu.com/ubuntu jammy/universe amd64 latex-cjk-thai all 4.8.4+git20170127-4 [76.0 kB]
# Get:278 http://archive.ubuntu.com/ubuntu jammy/universe amd64 latex-cjk-chinese-arphic-bsmi00lp all 1.23+nmu1 [15.1 MB]
# Get:279 http://archive.ubuntu.com/ubuntu jammy/universe amd64 latex-cjk-chinese-arphic-bkai00mp all 1.23+nmu1 [16.1 MB]
# Get:280 http://archive.ubuntu.com/ubuntu jammy/universe amd64 latex-cjk-chinese-arphic-gbsn00lp all 1.23+nmu1 [6,662 kB]
# Get:281 http://archive.ubuntu.com/ubuntu jammy/universe amd64 latex-cjk-chinese-arphic-gkai00mp all 1.23+nmu1 [7,382 kB]
# Get:282 http://archive.ubuntu.com/ubuntu jammy/universe amd64 latex-cjk-japanese-wadalab all 0.20050817-17.1 [17.8 MB]
# Get:283 http://archive.ubuntu.com/ubuntu jammy/universe amd64 latex-cjk-all all 4.8.4+git20170127-4 [930 B]
# Get:284 http://archive.ubuntu.com/ubuntu jammy/universe amd64 latexdiff all 1.3.1-1 [371 kB]
# Get:285 http://archive.ubuntu.com/ubuntu jammy/universe amd64 latexmk all 1:4.76-1 [171 kB]
# Get:286 http://archive.ubuntu.com/ubuntu jammy/universe amd64 lcdf-typetools amd64 2.108-2 [702 kB]
# Get:287 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libapache-pom-java all 18-1 [4,720 B]
# Get:288 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libclass-c3-xs-perl amd64 0.15-1build2 [16.7 kB]
# Get:289 http://archive.ubuntu.com/ubuntu jammy/main amd64 libclass-xsaccessor-perl amd64 1.19-3build9 [34.1 kB]
# Get:290 http://archive.ubuntu.com/ubuntu jammy/main amd64 libcommon-sense-perl amd64 3.75-2build1 [21.1 kB]
# Get:291 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libcommons-parent-java all 43-1 [10.8 kB]
# Get:292 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libcommons-logging-java all 1.2-2 [60.3 kB]
# ...
# Setting up fonts-dejavu-core (2.37-2build1) ...
# Setting up liblist-moreutils-xs-perl (0.430-2build2) ...
# Setting up fonts-texgyre (20180621-3.1) ...
# Setting up fonts-gfs-bodoni-classic (1.1-6) ...
# Setting up netpbm (2:10.0-15.4) ...
# Setting up libqt5core5a:amd64 (5.15.3+dfsg-2ubuntu0.2) ...
# Setting up fonts-linuxlibertine (5.3.0-6) ...
# Setting up liblingua-translit-perl (0.28-1) ...
# Setting up latexdiff (1.3.1-1) ...
# Setting up libfftw3-double3:amd64 (3.3.8-2ubuntu8) ...
# Setting up fonts-tlwg-norasi (1:0.7.3-1) ...
# Setting up texlive-pictures (2021.20220204-1) ...
# Setting up libparams-util-perl (1.102-1build3) ...
# Setting up fonts-tlwg-waree-otf (1:0.7.3-1) ...
# Setting up dvidvi (1.0-8.2) ...
# Setting up libmtdev1:amd64 (1.1.6-1build4) ...
# Setting up libsub-exporter-progressive-perl (0.001013-1) ...
# Setting up fonts-tlwg-sawasdee-otf (1:0.7.3-1) ...
# Setting up texlive-latex-recommended-doc (2021.20220204-1) ...
# Setting up fonts-croscore (20201225-1build1) ...
# Setting up texlive-lang-cyrillic (2021.20220204-1) ...
# Setting up ruby-webrick (1.7.0-3ubuntu0.1) ...
# Setting up libsub-name-perl (0.26-1build3) ...
# Setting up fonts-tlwg-typist-otf (1:0.7.3-1) ...
# Setting up libbusiness-ismn-perl (1.202-1) ...
# Setting up fonts-dejavu-extra (2.37-2build1) ...
# Setting up libtypes-serialiser-perl (1.01-1) ...
# Setting up latex-cjk-chinese-arphic-bsmi00lp (1.23+nmu1) ...
# Setting up texlive-lang-polish (2021.20220204-1) ...
# Setting up libparse-recdescent-perl (1.967015+dfsg-2) ...
# Setting up libostyle1c2 (1.4devel1-22) ...
# Setting up liblqr-1-0:amd64 (0.4.2-2.1) ...
# Setting up fonts-gfs-baskerville (1.1-6) ...
# Setting up fonts-ipafont-mincho (00303-21ubuntu1) ...
# Setting up fonts-ipafont-gothic (00303-21ubuntu1) ...
# Setting up libmime-charset-perl (1.012.2-1) ...
# Setting up libqt5dbus5:amd64 (5.15.3+dfsg-2ubuntu0.2) ...
# Setting up texlive-humanities-doc (2021.20220204-1) ...
# Setting up libbusiness-isbn-data-perl (20210112.006-1) ...
# Setting up libjson-perl (4.04000-1) ...
# Setting up fonts-gfs-complutum (1.1-7) ...
# Setting up fonts-tlwg-garuda (1:0.7.3-1) ...
# Setting up texlive-fonts-recommended (2021.20220204-1) ...
# Setting up librole-tiny-perl (2.002004-1) ...
# Setting up x11-utils (7.7+5build2) ...
# Setting up fonts-crosextra-caladea (20130214-2.1) ...
# Setting up libipc-run3-perl (0.048-2) ...
# Setting up libmd4c0:amd64 (0.4.8-1) ...
# Setting up libfile-sharedir-perl (1.118-1) ...
# Setting up libdevel-globaldestruction-perl (0.14-1.1) ...
# Setting up netbase (6.3) ...
# Setting up fonts-gfs-theokritos (1.1-6) ...
# Setting up sgml-base (1.30) ...
# Setting up libsub-quote-perl (2.006006-1) ...
# Setting up libdevel-stacktrace-perl (2.0400-1) ...
# Setting up fonts-baekmuk (2.2-13) ...
# Setting up libclass-xsaccessor-perl (1.19-3build9) ...
# Setting up fonts-tlwg-loma (1:0.7.3-1) ...
# Setting up libencode-hanextra-perl (0.23-5build4) ...
# Setting up texlive-pictures-doc (2021.20220204-1) ...
# Setting up fonts-ebgaramond-extra (0.016+git20210310.42d4f9f2-1) ...
# Setting up fonts-lobster (2.0-2.1) ...
# Setting up tipa (2:1.3-21) ...
# Setting up poppler-utils (22.02.0-2ubuntu0.7) ...
# Setting up libdjvulibre-text (3.5.28-2build2) ...
# Setting up texlive-latex-base-doc (2021.20220204-1) ...
# Setting up libbusiness-issn-perl (1.005-1) ...
# Setting up latex-cjk-common (4.8.4+git20170127-4) ...
# Setting up texlive-lang-cjk (2021.20220204-1) ...
# Setting up prerex (6.8.0-1) ...
# Setting up libexporter-tiny-perl (1.002002-1) ...
# Setting up libclass-accessor-perl (0.51-1) ...
# Setting up libtext-unidecode-perl (1.30-1) ...
# Setting up fonts-tlwg-kinnari-otf (1:0.7.3-1) ...
# Setting up libfile-homedir-perl (1.006-1) ...
# Setting up texlive-lang-european (2021.20220204-1) ...
# Setting up texlive-metapost-doc (2021.20220204-1) ...
# Setting up latex-cjk-japanese-wadalab (0.20050817-17.1) ...
# Setting up libsys-hostname-long-perl (1.5-2) ...
# Setting up libemf1:amd64 (1.0.13-3) ...
# Setting up psutils (1.17.dfsg-4) ...
# Setting up fonts-adf-gillius (0.20190904-2) ...
# Setting up libevdev2:amd64 (1.12.1+dfsg-1) ...
# Setting up libtext-roman-perl (3.5-2.1) ...
# Setting up openjade (1.4devel1-22) ...
# Setting up ruby-xmlrpc (0.3.2-1ubuntu0.1) ...
# Setting up fonts-noto-core (20201225-1build1) ...
# Setting up tex-gyre (20180621-3.1) ...
# Setting up fonts-font-awesome (5.0.10+really4.7.0~dfsg-4.1) ...
# Setting up liburi-perl (5.10-1) ...
# Setting up info (6.8-4build1) ...
# update-alternatives: using /usr/bin/info to provide /usr/bin/infobrowser (infobrowser) in auto mode
# Setting up asymptote-doc (2.78+ds-2) ...
# Setting up libgudev-1.0-0:amd64 (1:237-2build1) ...
# Setting up xbitmaps (1.1.1-2.1ubuntu1) ...
# Setting up latex-cjk-korean (4.8.4+git20170127-4) ...
# Setting up lcdf-typetools (2.108-2) ...
# Setting up chktex (1.7.6-4) ...
# Setting up libxm4:amd64 (2.3.8-3) ...
# Setting up texlive-publishers-doc (2021.20220204-1) ...
# Setting up fonts-tlwg-typewriter (1:0.7.3-1) ...
# Setting up texlive-music (2021.20220204-1) ...
# Setting up libhttp-message-perl (6.36-1) ...
# Setting up libtext-csv-perl (2.01-1) ...
# Setting up libwacom-common (2.2.0-1) ...
# Setting up cm-super-minimal (0.3.4-17) ...
# Setting up libnet-ssleay-perl:amd64 (1.92-1build2) ...
# Setting up texlive-pstricks (2021.20220204-1) ...
# Setting up libjson-xs-perl (4.030-1build3) ...
# Setting up libhttp-negotiate-perl (6.01-1) ...
# Setting up fonts-tlwg-typo (1:0.7.3-1) ...
# Setting up libpdfbox-java (1:1.8.16-2) ...
# Setting up libjxr-tools (1.2~git20170615.f752187-5) ...
# Setting up fonts-tlwg-waree (1:0.7.3-1) ...
# Setting up texlive-lang-korean (2021.20220204-1) ...
# Setting up libtext-bibtex-perl (0.88-3build3) ...
# Setting up libhttp-cookies-perl (6.10-1) ...
# Setting up texlive-publishers (2021.20220204-1) ...
# Setting up cups-bsd (2.4.1op1-1ubuntu4.11) ...
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78.)
# debconf: falling back to frontend: Readline
# Setting up libwacom9:amd64 (2.2.0-1) ...
# Setting up texlive-lang-czechslovak (2021.20220204-1) ...
# Setting up liblist-moreutils-perl (0.430-2) ...
# Setting up dvipng (1.15-1.1) ...
# Setting up libcommons-parent-java (43-1) ...
# Setting up libdjvulibre21:amd64 (3.5.28-2build2) ...
# Setting up fonts-tlwg-sawasdee (1:0.7.3-1) ...
# Setting up libcommons-logging-java (1.2-2) ...
# Setting up libnet-http-perl (6.22-1) ...
# Setting up texlive-latex-extra (2021.20220204-1) ...
# Setting up libtext-csv-xs-perl:amd64 (1.47-1build1) ...
# Setting up libipc-shareable-perl (1.06-2) ...
# Setting up texlive-lang-greek (2021.20220204-1) ...
# Setting up gsfonts-x11 (0.28) ...
# Setting up libexception-class-perl (1.45-1) ...
# Setting up fonts-tlwg-typist (1:0.7.3-1) ...
# Setting up libclass-c3-perl (0.35-1) ...
# Setting up libdevel-callchecker-perl (0.008-1ubuntu4) ...
# Setting up libxml-sax-perl (1.02+dfsg-3) ...
# update-perl-sax-parsers: Registering Perl SAX parser XML::SAX::PurePerl with priority 10...
# update-perl-sax-parsers: Updating overall Perl SAX parser modules info file...
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78.)
# debconf: falling back to frontend: Readline
#
# Creating config file /etc/perl/XML/SAX/ParserDetails.ini with new version
# Setting up texlive-lang-other (2021.20220204-1) ...
# Setting up fonts-lobstertwo (2.0-2.1) ...
# Setting up libqt5network5:amd64 (5.15.3+dfsg-2ubuntu0.2) ...
# Setting up libdata-compare-perl (1.27-1) ...
# Setting up libinput-bin (1.20.0-1ubuntu0.3) ...
# Setting up texlive-lang-chinese (2021.20220204-1) ...
# Setting up libmail-sendmail-perl (0.80-1.1) ...
# Setting up libmagickcore-6.q16-6:amd64 (8:6.9.11.60+dfsg-1.3ubuntu0.22.04.5) ...
# Setting up libqt5xml5:amd64 (5.15.3+dfsg-2ubuntu0.2) ...
# Setting up fonts-tlwg-kinnari (1:0.7.3-1) ...
# Setting up libunicode-linebreak-perl (0.0.20190101-1build3) ...
# Setting up libdata-optlist-perl (0.112-1) ...
# Setting up latex-cjk-japanese (4.8.4+git20170127-4) ...
# Setting up texlive-fonts-extra-links (2021.20220204-1) ...
# Setting up latex-cjk-chinese (4.8.4+git20170127-4) ...
# Setting up libxml-libxml-perl (2.0207+dfsg+really+2.0134-1) ...
# update-perl-sax-parsers: Registering Perl SAX parser XML::LibXML::SAX::Parser with priority 50...
# update-perl-sax-parsers: Registering Perl SAX parser XML::LibXML::SAX with priority 50...
# update-perl-sax-parsers: Updating overall Perl SAX parser modules info file...
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78.)
# debconf: falling back to frontend: Readline
# Replacing config file /etc/perl/XML/SAX/ParserDetails.ini with new version
# Setting up libwacom-bin (2.2.0-1) ...
# Setting up libwww-robotrules-perl (6.02-1) ...
# Setting up libhttp-daemon-perl (6.13-1ubuntu0.1) ...
# Setting up libhtml-parser-perl:amd64 (3.76-1build2) ...
# Setting up texlive-xetex (2021.20220204-1) ...
# Setting up libmagickwand-6.q16-6:amd64 (8:6.9.11.60+dfsg-1.3ubuntu0.22.04.5) ...
# Setting up cm-super (0.3.4-17) ...
# Creating fonts. This may take some time... done.
# Setting up xterm (372-1ubuntu1) ...
# update-alternatives: using /usr/bin/xterm to provide /usr/bin/x-terminal-emulator (x-terminal-emulator) in auto mode
# update-alternatives: using /usr/bin/lxterm to provide /usr/bin/x-terminal-emulator (x-terminal-emulator) in auto mode
# Setting up libmro-compat-perl (0.15-1) ...
# Setting up xpdf (3.04+git20220201-1) ...
# Setting up libmagick++-6.q16-8:amd64 (8:6.9.11.60+dfsg-1.3ubuntu0.22.04.5) ...
# Setting up libio-socket-ssl-perl (2.074-2) ...
# Setting up libsub-exporter-perl (0.988-1) ...
# Setting up libeval-closure-perl (0.14-1) ...
# Setting up libhtml-form-perl (6.07-1) ...
# Setting up libinput10:amd64 (1.20.0-1ubuntu0.3) ...
# Setting up libparams-validationcompiler-perl (0.30-1) ...
# Setting up libpstoedit0c2a:amd64 (3.78-1) ...
# Setting up libmagickcore-6.q16-6-extra:amd64 (8:6.9.11.60+dfsg-1.3ubuntu0.22.04.5) ...
# Setting up libhtml-tree-perl (5.07-2) ...
# Setting up libparams-classify-perl (0.015-1build5) ...
# Setting up libxml-libxml-simple-perl (1.01-1) ...
# Setting up latex-cjk-thai (4.8.4+git20170127-4) ...
# Setting up texlive-science (2021.20220204-1) ...
# Setting up libqt5gui5:amd64 (5.15.3+dfsg-2ubuntu0.2) ...
# Setting up libqt5widgets5:amd64 (5.15.3+dfsg-2ubuntu0.2) ...
# Setting up libhtml-format-perl (2.12-1.1) ...
# Setting up qt5-gtk-platformtheme:amd64 (5.15.3+dfsg-2ubuntu0.2) ...
# Setting up latex-cjk-all (4.8.4+git20170127-4) ...
# Setting up texlive-formats-extra (2021.20220204-1) ...
# Setting up libnet-smtp-ssl-perl (1.04-1) ...
# Setting up libmodule-runtime-perl (0.016-1) ...
# Setting up libmailtools-perl (2.21-1) ...
# Setting up texlive-extra-utils (2021.20220204-1) ...
# Setting up libdist-checkconflicts-perl (0.11-1.1) ...
# Setting up texinfo (6.8-4build1) ...
# Running mktexlsr. This may take some time. ... done.
# Setting up libxml-libxslt-perl (1.99-1build2) ...
# Setting up imagemagick-6.q16 (8:6.9.11.60+dfsg-1.3ubuntu0.22.04.5) ...
# update-alternatives: using /usr/bin/compare-im6.q16 to provide /usr/bin/compare (compare) in auto mode
# update-alternatives: using /usr/bin/compare-im6.q16 to provide /usr/bin/compare-im6 (compare-im6) in auto mode
# update-alternatives: using /usr/bin/animate-im6.q16 to provide /usr/bin/animate (animate) in auto mode
# update-alternatives: using /usr/bin/animate-im6.q16 to provide /usr/bin/animate-im6 (animate-im6) in auto mode
# update-alternatives: using /usr/bin/convert-im6.q16 to provide /usr/bin/convert (convert) in auto mode
# update-alternatives: using /usr/bin/convert-im6.q16 to provide /usr/bin/convert-im6 (convert-im6) in auto mode
# update-alternatives: using /usr/bin/composite-im6.q16 to provide /usr/bin/composite (composite) in auto mode
# update-alternatives: using /usr/bin/composite-im6.q16 to provide /usr/bin/composite-im6 (composite-im6) in auto mode
# update-alternatives: using /usr/bin/conjure-im6.q16 to provide /usr/bin/conjure (conjure) in auto mode
# update-alternatives: using /usr/bin/conjure-im6.q16 to provide /usr/bin/conjure-im6 (conjure-im6) in auto mode
# update-alternatives: using /usr/bin/import-im6.q16 to provide /usr/bin/import (import) in auto mode
# update-alternatives: using /usr/bin/import-im6.q16 to provide /usr/bin/import-im6 (import-im6) in auto mode
# update-alternatives: using /usr/bin/identify-im6.q16 to provide /usr/bin/identify (identify) in auto mode
# update-alternatives: using /usr/bin/identify-im6.q16 to provide /usr/bin/identify-im6 (identify-im6) in auto mode
# update-alternatives: using /usr/bin/stream-im6.q16 to provide /usr/bin/stream (stream) in auto mode
# update-alternatives: using /usr/bin/stream-im6.q16 to provide /usr/bin/stream-im6 (stream-im6) in auto mode
# update-alternatives: using /usr/bin/display-im6.q16 to provide /usr/bin/display (display) in auto mode
# update-alternatives: using /usr/bin/display-im6.q16 to provide /usr/bin/display-im6 (display-im6) in auto mode
# update-alternatives: using /usr/bin/montage-im6.q16 to provide /usr/bin/montage (montage) in auto mode
# update-alternatives: using /usr/bin/montage-im6.q16 to provide /usr/bin/montage-im6 (montage-im6) in auto mode
# update-alternatives: using /usr/bin/mogrify-im6.q16 to provide /usr/bin/mogrify (mogrify) in auto mode
# update-alternatives: using /usr/bin/mogrify-im6.q16 to provide /usr/bin/mogrify-im6 (mogrify-im6) in auto mode
# Setting up feynmf (1.08-13) ...
# Setting up libpoppler-qt5-1:amd64 (22.02.0-2ubuntu0.7) ...
# Setting up fragmaster (1.7-10) ...
# Setting up pstoedit (3.78-1) ...
# Setting up libmime-lite-perl (3.033-1) ...
# Setting up libmodule-implementation-perl (0.09-1.1) ...
# Setting up libpackage-stash-perl (0.39-1) ...
# Setting up libqt5svg5:amd64 (5.15.3-1) ...
# Setting up liblist-someutils-perl (0.58-1) ...
# Setting up vprerex (1:6.5.1-1build1) ...
# Setting up asymptote (2.78+ds-2) ...
# Setting up libspecio-perl (0.47-1) ...
# Setting up liblist-someutils-xs-perl (0.58-2build3) ...
# Setting up liblist-allutils-perl (0.19-1) ...
# Setting up imagemagick (8:6.9.11.60+dfsg-1.3ubuntu0.22.04.5) ...
# Setting up libparams-validate-perl:amd64 (1.30-1build3) ...
# Setting up libb-hooks-endofscope-perl (0.25-1) ...
# Setting up purifyeps (1.1-3) ...
# Setting up libnamespace-clean-perl (0.27-1) ...
# Setting up libnamespace-autoclean-perl (0.29-1) ...
# Setting up libdatetime-locale-perl (1:1.33-1) ...
# Setting up libdatetime-timezone-perl (1:2.51-1+2021e) ...
# Setting up liblog-dispatch-perl (2.70-1) ...
# Setting up libdatetime-perl:amd64 (2:1.55-1build1) ...
# Setting up libdatetime-format-strptime-perl (1.7900-1) ...
# Setting up libdatetime-calendar-julian-perl (0.107-1) ...
# Setting up libdatetime-format-builder-perl (0.8300-1) ...
# Setting up libwww-perl (6.61-1) ...
# Setting up ruby-rubygems (3.3.5-2) ...
# Setting up libbusiness-isbn-perl (3.006-1) ...
# Setting up rake (13.0.6-2) ...
# Setting up liblwp-protocol-https-perl (6.10-1) ...
# Setting up libxml-parser-perl:amd64 (2.46-3build1) ...
# Setting up libruby3.0:amd64 (3.0.2-7ubuntu2.10) ...
# Setting up ruby3.0 (3.0.2-7ubuntu2.10) ...
# Setting up libxml-sax-expat-perl (0.51-1) ...
# update-perl-sax-parsers: Registering Perl SAX parser XML::SAX::Expat with priority 50...
# update-perl-sax-parsers: Updating overall Perl SAX parser modules info file...
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78.)
# debconf: falling back to frontend: Readline
# Replacing config file /etc/perl/XML/SAX/ParserDetails.ini with new version
# Setting up biber (2.17-2) ...
# Setting up ruby (1:3.0~exp1) ...
# Setting up texlive-lang-japanese (2021.20220204-1) ...
# Setting up context (2021.03.05.20220211-1) ...
# Running mtxrun --generate. This may take some time... done.
# Pregenerating ConTeXt MarkIV format. This may take some time...

# %%
pdfl = PDFLaTeX.from_texfile('pitch.tex')
pdf, log, completed_process = pdfl.create_pdf(keep_pdf_file = True)
with open('output.pdf', 'wb') as f:
    f.write(pdf)
